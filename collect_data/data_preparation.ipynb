# %% [markdown]
# # RCE - Archaeology Data extraction and preparation
#
# This notebook contains code for the extraction of the Archaeology Data Station metadata (based on DOIs that were provided to me prior to this work). It extracts data from zips, takes DOIs and allows for the filtering on certain metadata fields (e.g. selecting only DOIs with missing geospatial data, dendrochronology data etc).
#
# Goal of this notebook:
# - Extract DOIs
# - Filter data
# - Initial data exploration: How many datasets do not have geospatial information? What values can the coordinate fields take (i.e. what are the reference system formats)?

# %% [markdown]
# ## Explore

# %%
import pandas as pd
import zipfile

# %%
# Starting this project, two zip files were handed to me by the DANS team. 
# One contains all Archaeology metadata, the other contains DataverseNL metadata, including dendrochronology.


# Paths to the zip files
#zip_file_1 = '../data/explore/metadata-1.zip' # DataverseNL metadata, incl dendrochronology 
zip_file_2 = '../../data/explore/metadata-2.zip' # Archaeology metadata

# %%
### Inspect zip file contents 

# Path to zip file
zip_file_path = '../../data/explore/metadata-2.zip'
#zip_file_path = '../data/explore/metadata-1.zip'

# Open the zip file and list its contents
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_contents = zip_ref.namelist()  # List all files inside the zip
    print("Files in the ZIP archive:")
    for file in zip_contents:
        print(file)
# Out:
# Files in the ZIP archive:
# metadata-16-01-2025/
# metadata-16-01-2025/getmetadata.sh
# metadata-16-01-2025/metadata-from-prod-server-0.csv
# metadata-16-01-2025/metadata-from-prod-server-1.csv
# metadata-16-01-2025/metadata-from-prod-server-10.csv
# metadata-16-01-2025/metadata-from-prod-server-11.csv
# metadata-16-01-2025/metadata-from-prod-server-12.csv
# metadata-16-01-2025/metadata-from-prod-server-13.csv
# metadata-16-01-2025/metadata-from-prod-server-14.csv
# metadata-16-01-2025/metadata-from-prod-server-15.csv
# metadata-16-01-2025/metadata-from-prod-server-16.csv
# metadata-16-01-2025/metadata-from-prod-server-17.csv
# metadata-16-01-2025/metadata-from-prod-server-18.csv
# metadata-16-01-2025/metadata-from-prod-server-19.csv
# metadata-16-01-2025/metadata-from-prod-server-2.csv
# metadata-16-01-2025/metadata-from-prod-server-20.csv
# metadata-16-01-2025/metadata-from-prod-server-21.csv
# metadata-16-01-2025/metadata-from-prod-server-22.csv
# metadata-16-01-2025/metadata-from-prod-server-23.csv
# metadata-16-01-2025/metadata-from-prod-server-24.csv
# metadata-16-01-2025/metadata-from-prod-server-25.csv
# metadata-16-01-2025/metadata-from-prod-server-26.csv
# metadata-16-01-2025/metadata-from-prod-server-27.csv
# metadata-16-01-2025/metadata-from-prod-server-28.csv
# metadata-16-01-2025/metadata-from-prod-server-29.csv
# metadata-16-01-2025/metadata-from-prod-server-3.csv
# metadata-16-01-2025/metadata-from-prod-server-30.csv
# metadata-16-01-2025/metadata-from-prod-server-31.csv
# metadata-16-01-2025/metadata-from-prod-server-4.csv
# metadata-16-01-2025/metadata-from-prod-server-5.csv
# metadata-16-01-2025/metadata-from-prod-server-6.csv
# metadata-16-01-2025/metadata-from-prod-server-7.csv
# metadata-16-01-2025/metadata-from-prod-server-8.csv
# metadata-16-01-2025/metadata-from-prod-server-9.csv

# %%
### Load the metadata from all CSV files in the zip file into a single DataFrame 

# Path to your zip file
zip_file_path = '../../data/explore/metadata-2.zip'

# Create an empty DataFrame
df = pd.DataFrame()

# Open the zip file
with zipfile.ZipFile(zip_file_path, 'r') as z:
    # List all files in the zip
    for filename in z.namelist():
        if filename.endswith('.csv'):
            # Read each CSV file into a DataFrame
            with z.open(filename) as f:
                d = pd.read_csv(f)
                # Append to the combined DataFrame
                df = pd.concat([df, d], ignore_index=True)

# Display the combined DataFrame
df.head()
# Out:
#                dsPersistentId publicationStatus  \
# 0  doi:10.17026/dans-zrj-unr7         Published
# 1  doi:10.17026/dans-299-9dpm         Published
# 2  doi:10.17026/dans-zqy-ymw8         Published
# 3  doi:10.17026/dans-z8d-9c6h         Published
# 4  doi:10.17026/dans-x9v-j3qu         Published
#
#                                                title  \
# 0                   Gouda Kattensingel Booronderzoek
# 1                                 Zandwingebied Q10R
# 2   Kerkrade Landgraaf buffer Kraanweg Booronderzoek
# 3  Archeologisch Bureauonderzoek en Inventarisere...
# 4  Archeologisch Bureauonderzoek Reconstructie Si...
#
#                                   dsDescriptionValue     dansSpatialPointX  \
# 0  ADC ArcheoProjecten heeft in januari 2017 een ...                108240
# 1  In opdracht van- en in samenwerking met Rijksw...                 77230
# 2  ADC ArcheoProjecten heeft in december 2016 een...                203505
# 3  In het kader van de vergunningverlening ten be...                 95873
# 4  In het kader van de vergunningverlening ten be...  197332,197337,197185
#
#       dansSpatialPointY            dansSpatialPointScheme dansSpatialBoxNorth  \
# 0                447370                        RD (in m.)                 NaN
# 1                490214                        RD (in m.)                 NaN
# 2                324100                        RD (in m.)                 NaN
# 3                421799                        RD (in m.)                 NaN
# 4  356659,356100,355712  RD (in m.),RD (in m.),RD (in m.)                 NaN
#
#   dansSpatialBoxEast dansSpatialBoxSouth dansSpatialBoxWest  \
# 0                NaN                 NaN                NaN
# 1                NaN                 NaN                NaN
# 2                NaN                 NaN                NaN
# 3                NaN                 NaN                NaN
# 4                NaN                 NaN                NaN
#
#   dansSpatialBoxScheme  dansSpatialCoverageControlleddansSpatialCoverageText
# 0                  NaN                                                NaN
# 1                  NaN                                                NaN
# 2                  NaN                                                NaN
# 3                  NaN                                                NaN
# 4                  NaN                                                NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 159289 entries, 0 to 159288
# Data columns (total 13 columns):
#  #   Column                                                Non-Null Count   Dtype
# ---  ------                                                --------------   -----
#  0   dsPersistentId                                        159289 non-null  object
#  1   publicationStatus                                     159289 non-null  object
#  2   title                                                 159289 non-null  object
#  3   dsDescriptionValue                                    159289 non-null  object
#  4   dansSpatialPointX                                     56945 non-null   object
#  5   dansSpatialPointY                                     56944 non-null   object
#  6   dansSpatialPointScheme                                56732 non-null   object
#  7   dansSpatialBoxNorth                                   4445 non-null    object
#  8   dansSpatialBoxEast                                    4444 non-null    object
#  9   dansSpatialBoxSouth                                   4438 non-null    object
#  10  dansSpatialBoxWest                                    4436 non-null    object
#  11  dansSpatialBoxScheme                                  4452 non-null    object
#  12  dansSpatialCoverageControlleddansSpatialCoverageText  0 non-null       float64
# dtypes: float64(1), object(12)
# memory usage: 15.8+ MB

# %%
df
# Out:
#                     dsPersistentId publicationStatus  \
# 0       doi:10.17026/dans-zrj-unr7         Published
# 1       doi:10.17026/dans-299-9dpm         Published
# 2       doi:10.17026/dans-zqy-ymw8         Published
# 3       doi:10.17026/dans-z8d-9c6h         Published
# 4       doi:10.17026/dans-x9v-j3qu         Published
# ...                            ...               ...
# 159284      doi:10.17026/AR/H4IDSE         Published
# 159285      doi:10.17026/AR/19BCUB         Published
# 159286      doi:10.17026/AR/QXOI5Q         Published
# 159287      doi:10.17026/AR/QHHAGE         Published
# 159288      doi:10.17026/AR/FBKZM2         Published
#
#                                                     title  \
# 0                        Gouda Kattensingel Booronderzoek
# 1                                      Zandwingebied Q10R
# 2        Kerkrade Landgraaf buffer Kraanweg Booronderzoek
# 3       Archeologisch Bureauonderzoek en Inventarisere...
# 4       Archeologisch Bureauonderzoek Reconstructie Si...
# ...                                                   ...
# 159284  IVO-karterende fase zonnepark Groot Roodehaan,...
# 159285  Gemeente Moerdijk plangebied de Kogelvangers t...
# 159286  Archeologisch bureauonderzoek perceel tussen K...
# 159287  Archeologisch bureauonderzoek Den Ilp 53a te D...
# 159288  Archeologisch bureauonderzoek Oorgat 6-6a te E...
#
#                                        dsDescriptionValue  \
# 0       ADC ArcheoProjecten heeft in januari 2017 een ...
# 1       In opdracht van- en in samenwerking met Rijksw...
# 2       ADC ArcheoProjecten heeft in december 2016 een...
# 3       In het kader van de vergunningverlening ten be...
# 4       In het kader van de vergunningverlening ten be...
# ...                                                   ...
# 159284  Laagland Archeologie heeft in april 2021 een k...
# 159285  Op basis van het bureauonderzoek geldt er voor...
# 159286  In november 2021 is een archeologisch bureauon...
# 159287  In november 2021 is in opdracht van een partic...
# 159288  In oktober 2021 is een archeologisch bureauond...
#
#                          dansSpatialPointX  \
# 0                                   108240
# 1                                    77230
# 2                                   203505
# 3                                    95873
# 4                     197332,197337,197185
# ...                                    ...
# 159284  238853,238979,239404,239437,239175
# 159285                                 NaN
# 159286                             101.391
# 159287                             122.592
# 159288                             133.371
#
#                          dansSpatialPointY  \
# 0                                   447370
# 1                                   490214
# 2                                   324100
# 3                                   421799
# 4                     356659,356100,355712
# ...                                    ...
# 159284  579376,579083,579242,579530,579532
# 159285                                 NaN
# 159286                             497.243
# 159287                             495.815
# 159288                             503.251
#
#                              dansSpatialPointScheme dansSpatialBoxNorth  \
# 0                                        RD (in m.)                 NaN
# 1                                        RD (in m.)                 NaN
# 2                                        RD (in m.)                 NaN
# 3                                        RD (in m.)                 NaN
# 4                  RD (in m.),RD (in m.),RD (in m.)                 NaN
# ...                                             ...                 ...
# 159284  RD (in m.),RD (in m.),RD (in m.),RD (in m.)                 NaN
# 159285                                          NaN              411813
# 159286                                   RD (in m.)                 NaN
# 159287                                          NaN                 NaN
# 159288                                   RD (in m.)                 NaN
#
#        dansSpatialBoxEast dansSpatialBoxSouth dansSpatialBoxWest  \
# 0                     NaN                 NaN                NaN
# 1                     NaN                 NaN                NaN
# 2                     NaN                 NaN                NaN
# 3                     NaN                 NaN                NaN
# 4                     NaN                 NaN                NaN
# ...                   ...                 ...                ...
# 159284                NaN                 NaN                NaN
# 159285              90282              411486              89850
# 159286                NaN                 NaN                NaN
# 159287                NaN                 NaN                NaN
# 159288                NaN                 NaN                NaN
#
#        dansSpatialBoxScheme  \
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
# ...                     ...
# 159284                  NaN
# 159285           RD (in m.)
# 159286                  NaN
# 159287                  NaN
# 159288                  NaN
#
#         dansSpatialCoverageControlleddansSpatialCoverageText
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 159284                                                NaN
# 159285                                                NaN
# 159286                                                NaN
# 159287                                                NaN
# 159288                                                NaN
#
# [159289 rows x 13 columns]

# %%
# Take a look at some titles 
titles = df.title.tolist()
for title in titles[:100]:
    print(title)
    print()
# Out:
# Gouda Kattensingel Booronderzoek
#
# Zandwingebied Q10R
#
# Kerkrade Landgraaf buffer Kraanweg Booronderzoek
#
# Archeologisch Bureauonderzoek en Inventariserend Veldonderzoek door middel van grondboringen, verkennend, Planlocatie Zuiddijk 14b te Maasdam, Gemeente Binnenmaas
#
# Archeologisch Bureauonderzoek Reconstructie Singelring, Fase 1 en 2, Roermond, Gemeente Roermond
#
# Proefsleuvenonderzoek Erf 1 en Erf 12 in het tracé van de N18 Varsseveld-Enschede
#
# Archeologisch onderzoek Vughtse Hoeve, Vught
#
# Bureauonderzoek en Inventariserend veldonderzoek verkennende fase Uddelerveen 97 te Uddel
#
# Bureauonderzoek en inventariserend veldonderzoek d.m.v. boringen (verkennende fase) Onder de Mast en Vincent van Goghstraat te Zundert
#
# Zevenhuizen, Wollenfoppeweg 109 (Gemeente Zuidplas)  Een Bureauonderzoek
#
# Archeologisch Bureauonderzoek en Inventariserend Veldonderzoek door middel van grondboringen Plangebied Sectie AF, nr. 1879 (gedeeltelijk), Ovezande, Gemeente Borsele
#
# Vier locaties in en nabij de Oisterwijkse Hoeven. Sparredreef en Hoevense Weg (gemeente Oisterwijk). Een bureauonderzoek en verkennend booronderzoek. ArGeoBoor rapport 1301
#
# Domburg Land van Vliedduin. Gemeente Veere.
#
# Inventariserend Veldonderzoek door middel van Proefsleuven Plangebied Amberdreef, Papendrecht, Gemeente Papendrecht
#
# Bureauonderzoek en Inventariserend veldonderzoek verkennende fase Hoog Geldrop 59 te Geldrop
#
# Assen, Roegoorn en Schatgoorn (Gemeente Assen). Een bureauondezoek en verkennend booronderzoek. ArGeoBoor rapport 1350
#
# Bureauonderzoek en Inventariserend veldonderzoek verkennende fase Molenbosstraat 6 te Ossendrecht
#
# Croimvort, Gemeente Vught. Plangebied Golfbaan, drie aanvullende locaties. Inventariserend veldonderzoek (verkennende fase)
#
# Gemeente Reimerswaal, Kruiningen. Hansweertsestraatweg 1. Een bureauonderzoek en een inventariserend veldonderzoek door middel van verkennend booronderzoek. ArGeoBoor rapport 1362
#
# Rapport Archeologisch onderzoek (15111996) Rijksstraatweg ong. te Buurmalsen
#
# Goudsmidsgaarde, gemeente Den Haag
#
# Archeologisch bureauonderzoek Opwaardering 380kV verbinding Diemen-Lelystad (DIM-LLS380)
#
# Rolde, Nijlanderstraat (Gemeente Aa en Hunze) Herstel zandverstuiving Boerbos  Een verkennend booronderzoek. ArGeoBoor rapport 1382
#
# Archeologisch bureau- en booronderzoek fiets- en wandelpad Langelaan te Burgum, gemeente Tytsjerksteradiel (FR)
#
# Waarde – Weelweg KRW2016: Locatie 44. Gemeente Reimerswaal.
#
# Archeologische begeleiding onder protocol opgraven terrein St. Josephstraat / Brugske te Nederweert
#
# Roermond Laurentiusplein IVO
#
# Inventariserend Veldonderzoek door middel van Proefsleuven 'Plangebied LIDL Supermarkt', Oedsmawei en J. W. de Visserwei', Grou, Gemeente Leeuwarden
#
# Gieterveen, Streek 17 (Gemeente Aa en Hunze) Een verkennend booronderzoek.      ArGeoBoor rapport 1390
#
# Groningen, Oosterpoort, Palmslag en Veemarktstraat, Gemeente Groningen (Gr.). Archeologische Begeleiding
#
# Archeologisch bureau- en booronderzoek aan de Hoogevoort 8 t/m 36 te Castricum
#
# Sluis, Van Dalestraat/Geweldigersstraat, Van Dalestraat/1 Novemberstraat te Sluis, gem. Sluis (Z).
#
# 15045469 LIN.WRL.ARC Eindrapportage archeologisch onderzoek Waterberging Doornenburg te Doornenburg
#
# ’s-Heer Hendrikskinderen Nieuwe Rijksweg 2B. Gemeente Goes
#
# Lijnden, Raasdorperweg 43 (Gemeente Haarlemmermeer)  Een archeologisch bureauonderzoek          ArGeoBoor rapport 1400
#
# Bureauonderzoek en Inventariserend veldonderzoek verkennende fase Goorstraat (ong.) te Soerendonk
#
# Archeologisch bureauonderzoek Winsumerstraatweg 8 te Winsum, gemeente Winsum (GR)
#
# Ter Apelerstraat 30 Te Sellingen (Gemeente Vlagtwedde). Een verkennend booronderzoek. ArGeoBoor rapport 1316
#
# Bosackers, Beilerstraat 38, Assen, gemeente Assen: een bureau- en inventariserend veldonderzoek in de vorm van boringen
#
# Archeologisch Bureauonderzoek & Inventariserend Veldonderzoek (IVO), verkennende fase; Kloosterweg, Brielle, Gemeente Brielle
#
# Bureauonderzoek en inventariserend veldonderzoek d.m.v. boringen (verkennende fase) Keenseweg te Etten-Leur (gemeente Etten-Leur)
#
# Bureauonderzoek plangebied Schilligeham, Reitdiep  gemeente Winsum; Antea Group Archeologie 2015/166
#
# Archeologische begeleiding aanleg rioolpersleiding te Oldemarkt en Paasloo,  gemeente Steenwijkerland (OV)
#
# Aanvullend archeologisch onderzoek in Monster-Poeldijk, 'vindplaatsen A en B'
#
# Boezem 13, Streefkerk, gemeente Molenwaard: een bureau- en inventariserend veldonderzoek in de vorm van boringen en landschappelijke cultuurhistorische analyse
#
# Inventariserend Veldonderzoek door middel van grondboringen (verkennende fase) Bedrijventerrein Kickersbloem 3, Zuidelijk en Noordelijk Deelgebied, Hellevoetsluis, Gemeente Hellevoetsluis
#
# Dwars door het dorp. Een archeologische begeleiding door het centrum van Geldermalsen
#
# Archeologisch proefsleuven-onderzoek en opgraving aan Sinderenseweg 72 te Sinderen, gemeente Oude IJsselstreek (GLD)
#
# Namweg, Nijeveen, gemeente Meppel: een bureau- en inventariserend veldonderzoek in de vorm van boringen
#
# Archeologisch Bureauonderzoek & Inventariserend Veldonderzoek (IVO), karterende fase: Nieuw Leyden veld 3 en 4, Gemeente Leiden
#
# Gemeente Oss. Plangebied Weverstraat te Geffen
#
# Proefsleuvenonderzoek Professor Uilkensweg, Groningen, gemeente Groningen; Antea Group Archeologie 2015/120
#
# Bovendijk 5, Ammerzoden, gemeente Maasdriel: een bureau- en inventariserend veldonderzoek in de vorm van boringen
#
# Archeologisch bureauonderzoek & Inventariserend Veldonderzoek, verkennende fase: Werkensedijk 69, Werkendam, Gemeente Werkendam
#
# Bureauonderzoek en Inventariserend Veldonderzoek, karterende fase: Noordbargerstraat 19 te Emmen
#
# Archeologisch bureauonderzoek en Inventariserend veldonderzoek, verkennende fase  Kerkstraat, Oude Wetering  Gemeente Alkemade
#
# Landgoed Leeuwenhorst, Noordwijkerhout, gemeente Noordwijkerhout: een bureau- en inventariserend veldonderzoek in de vorm van boringen
#
# Bureauonderzoek en Inventariserend veldonderzoek verkennende/karterende fase Landgoed Kromme Hoek te Neerloon
#
# Bureauonderzoek en inventariserend veldonderzoek door middel van verkennende boringen twee rotondes te Putten (Gld.)
#
# Inventariserend veldonderzoek - verkennende fase Beulakerweg 127 te Giethoorn
#
# Hiaure, Hantumerwei 16 (gemeente Dongeradeel). Een bureauonderzoek en karterend booronderzoek.
#
# Archeologische begeleiding aanbrengen nieuwe vloer in de kerk te Ezinge, gemeente Winsum (GR)
#
# Archeologisch bureauonderzoek Bussereindseweg 10 te Beesel in de gemeente Beesel
#
# Zwijndrecht Saturnusstraat
#
# Bureauonderzoek en inventariserend veldonderzoek door middel van boringen Lucent-terrein Larenseweg te Hilversum
#
# Torenlaan 5a, Voorhout, Gemeente Teylingen
#
# Gennep. Plangebied Genneperhuisweg en een gedeelte van de Haspel. Archeologisch bureauonderzoek
#
# Achtersteweg 11C, Nuland, gemeente 's-Hertogenbosch: een bureau- en inventariserend veldonderzoek in de vorm van boringen
#
# Inventariserend Veldonderzoek door middel van grondboringen (verkennende fase) 'Plangebied Julianastraat 54', Zuidland, Gemeente Nissewaard
#
# Sneek, Zuidwesthoekweg 2, Gemeente Súdwest-Fryslân (Fr.). Een Inventariserend Archeologisch Veldonderzoek
#
# Archeologisch Bureauonderzoek & Inventariserend Veldonderzoek (IVO), verkennende fase; Korte Nieuwstraat, Sprang-Capelle, Gemeente Waalwijk
#
# Coevorden, twee gebieden tussen de N34 en het Dwarspad (Gemeente Coevorden) Zonneakker ‘De Watering’    Een archeologisch bureauonderzoek
#
# Bureauonderzoek en Inventariserend Veldonderzoek, verkennende fase: Rottegatsteeg 5 te Maarsbergen
#
# Yerseke – Molenpolder. Gemeente Reimerswaal.
#
# Wijk aan Duinpad 18, Heemskerk, gemeente Heemskerk: een bureauonderzoek
#
# Willeskop 90, Montfoort, gemeente Montfoort: een bureau- en inventariserend veldonderzoek in de vorm van boringen
#
# Poelenburgh 1, Monster, gemeente Westland: een bureau- en inventariserend veldonderzoek in de vorm van boringen
#
# Archeologische Begeleiding aanleg wegcunet en Opgraving aanleg watervoorziening Hoge Meet, Stelleweg/Oranjeweg, Gemeente Goes
#
# Archeologische begeleiding van de sanering van zinkassen Brinkweg te Waalre in de gemeente Waalre
#
# BO en IVO-O Prins Willem Alexanderlaan, PWA-zone, Apeldoorn
#
# Archeologisch gecombineerd verkennend en karterend booronderzoek Boven Boukoul 48 te Swalmen in de gemeente Roermond
#
# Plangebied Sionsweg 10 te Rijswijk, Bureauonderzoek en Inventariserend veldonderzoek (verkennende fase)
#
# Archeologisch Bureauonderzoek en Inventariserend Veldonderzoek door middel van grondboringen 'Plangebied Van Hertumweg 15', Goes, Gemeente Goes
#
# Bureauonderzoek en Inventariserend Veldonderzoek, verkennende fase: Dennendijk 2a en 2b te Zutphen
#
# Prins Bernhardplein, Kaatsheuvel, Gemeente Loon op Zand
#
# Valkenswaard, Zeelbergse akkers - AAO
#
# Archeologisch bureauonderzoek; Voorstraat 53-55 te Beesd in de gemeente Geldermalsen
#
# DPO leiding Best - Glons, knelpunt 13, Akkerweg te Wintelre
#
# Hellevoetsluis, Groote Dok Oost
#
# Driekoppenland, Noorden, gemeente Nieuwkoop: een inventariserend veldonderzoek in de vorm van boringen, karterende fase
#
# Hoogwoud, Herenweg 64, hoek Oosterboekelweg (gemeente Opmeer)
#
# Gemeente Cuijk. Plangebied Achterdijk-RWZI te Haps
#
# Schoepikstraat 9 te Duiven, gemeente Duiven
#
# Archeologisch Bureauonderzoek met controleboringen Oudelandsedijk 20, Tholen, Gemeente Tholen
#
# Archeologisch Bureauonderzoek en Inventariserend Veldonderzoek door middel van grondboringen 'Bedrijventerrein Welgelegen III', Nieuwe Postweg, Tholen, Gemeente Tholen
#
# Heumen, Sluisweg, vooronderzoek
#
# Schiedam 'Land van Belofte'
#
# Archeologisch bureauonderzoek en verkennend booronderzoek Bisschop Zwijsenstraat (ong.) te Tilburg in de gemeente Tilburg
#
# Archeologisch bureauonderzoek Kanaaldijk Zuid 24 te Son in de gemeente Son en Breugel
#
# Gemeente Landerd, Plangebied MC Driehuis te Reek, Zandvoortseweg

# %%
# Inspect values of publicationStatus
pubstatus = df.publicationStatus.value_counts()
print(pubstatus)
# Out:
# publicationStatus
# Published                      158254
# Unpublished,Draft                 703
# Unpublished,Draft,In Review       179
# Deaccessioned                     109
# Draft                              44
# Name: count, dtype: int64

# %%
# Inspect values of dansSpatialPointScheme
status = df.dansSpatialBoxScheme.value_counts()
print(status)
# Out:
# dansSpatialBoxScheme
# RD (in m.)                                                                                                                                                                                    4175
# RD (in m.),RD (in m.)                                                                                                                                                                          168
# RD (in m.),RD (in m.),RD (in m.)                                                                                                                                                                40
# longitude/latitude (degrees)                                                                                                                                                                    29
# RD (in m.),RD (in m.),RD (in m.),RD (in m.)                                                                                                                                                     20
# RD (in m.),RD (in m.),RD (in m.),RD (in m.),RD (in m.)                                                                                                                                           6
# RD (in m.),RD (in m.),RD (in m.),RD (in m.),RD (in m.),RD (in m.)                                                                                                                                4
# RD (in m.),RD (in m.),RD (in m.),RD (in m.),RD (in m.),RD (in m.),RD (in m.),RD (in m.)                                                                                                          2
# RD (in m.),RD (in m.),RD (in m.),RD (in m.),RD (in m.),RD (in m.),RD (in m.),RD (in m.),RD (in m.),RD (in m.),RD (in m.),RD (in m.),RD (in m.),RD (in m.),RD (in m.),RD (in m.),RD (in m.)       1
# RD (in m.),RD (in m.),RD (in m.),RD (in m.),RD (in m.),RD (in m.),RD (in m.),RD (in m.),RD (in m.),RD (in m.),RD (in m.)                                                                         1
# RD (in m.),RD (in m.),RD (in m.),RD (in m.),RD (in m.),RD (in m.),RD (in m.),RD (in m.),RD (in m.),RD (in m.)                                                                                    1
# longitude/latitude (degrees),longitude/latitude (degrees)                                                                                                                                        1
# longitude/latitude (degrees),RD (in m.)                                                                                                                                                          1
# RD (in m.),RD (in m.),RD (in m.),RD (in m.),RD (in m.),RD (in m.),RD (in m.),RD (in m.),RD (in m.),RD (in m.),RD (in m.),RD (in m.),RD (in m.),RD (in m.),RD (in m.),RD (in m.)                  1
# RD (in m.),RD (in m.),RD (in m.),RD (in m.),RD (in m.),RD (in m.),RD (in m.),RD (in m.),RD (in m.)                                                                                               1
# RD (in m.),RD (in m.),RD (in m.),RD (in m.),RD (in m.),RD (in m.),RD (in m.)                                                                                                                     1
# Name: count, dtype: int64

# %%
# Count missing values 
nan_counts = df.isna().sum()

# %%
# Select only published datasets
df_pub = df[df.publicationStatus == 'Published']

# %%
df_pub.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 158254 entries, 0 to 159288
# Data columns (total 13 columns):
#  #   Column                                                Non-Null Count   Dtype
# ---  ------                                                --------------   -----
#  0   dsPersistentId                                        158254 non-null  object
#  1   publicationStatus                                     158254 non-null  object
#  2   title                                                 158254 non-null  object
#  3   dsDescriptionValue                                    158254 non-null  object
#  4   dansSpatialPointX                                     56479 non-null   object
#  5   dansSpatialPointY                                     56479 non-null   object
#  6   dansSpatialPointScheme                                56304 non-null   object
#  7   dansSpatialBoxNorth                                   4432 non-null    object
#  8   dansSpatialBoxEast                                    4430 non-null    object
#  9   dansSpatialBoxSouth                                   4426 non-null    object
#  10  dansSpatialBoxWest                                    4424 non-null    object
#  11  dansSpatialBoxScheme                                  4438 non-null    object
#  12  dansSpatialCoverageControlleddansSpatialCoverageText  0 non-null       float64
# dtypes: float64(1), object(12)
# memory usage: 16.9+ MB

# %%
# # Save the archeological datasets to a CSV file
# df_pub.to_csv('../data/archaeology_metadata.csv', index=False)

# %%
# Make a list of DOIs
dois = df_pub.dsPersistentId.tolist()

# %%
print(len(dois))
# Out:
# 158254

# %% [markdown]
# ## Get OAI-ORE metadata

# %% [markdown]
# ### Random sample
# This random sample was used in early stages of the project to gain insight into the data

# %%
# Get a random sample of 50 dois 
import random 
random_dois = random.sample(dois, 50)

# %%
[doi for doi in random_dois]
# Out:
# ['doi:10.17026/dans-z57-f4fs',
#  'doi:10.17026/dans-2x9-exy3',
#  'doi:10.17026/dans-zqu-8kyx',
#  'doi:10.17026/dans-zdb-m5db',
#  'doi:10.17026/dans-zg2-yta9',
#  'doi:10.17026/dans-zfy-2gdd',
#  'doi:10.17026/dans-x37-rmm8',
#  'doi:10.17026/dans-z8v-p5cy',
#  'doi:10.17026/dans-25m-9ymv',
#  'doi:10.17026/dans-x6m-sccp',
#  'doi:10.17026/dans-x4t-muar',
#  'doi:10.17026/dans-2au-kcam',
#  'doi:10.17026/dans-285-apxe',
#  'doi:10.17026/dans-zfn-z8y9',
#  'doi:10.17026/dans-zzy-p4ba',
#  'doi:10.17026/dans-z2c-54wb',
#  'doi:10.17026/dans-xnv-a4nm',
#  'doi:10.17026/dans-29s-w6tm',
#  'doi:10.17026/dans-zf2-zmht',
#  'doi:10.17026/dans-xbg-c7j8',
#  'doi:10.17026/dans-xkq-tquj',
#  'doi:10.17026/AR/QOU0ZC',
#  'doi:10.17026/AR/XAOIC8',
#  'doi:10.17026/dans-xpk-bhv4',
#  'doi:10.17026/dans-xvk-d9hq',
#  'doi:10.17026/dans-xeq-vgkx',
#  'doi:10.17026/dans-zp9-zkyz',
#  'doi:10.17026/AR/ANY5BC',
#  'doi:10.17026/dans-xcw-hg57',
#  'doi:10.17026/dans-zpn-sq97',
#  'doi:10.17026/dans-xvp-4u9g',
#  'doi:10.17026/dans-xhc-2d9n',
#  'doi:10.17026/dans-zfh-cas8',
#  'doi:10.17026/dans-zn4-8dfg',
#  'doi:10.17026/dans-zhg-ee9q',
#  'doi:10.17026/dans-zxs-6mzk',
#  'doi:10.17026/dans-27p-jge8',
#  'doi:10.17026/dans-z8g-gp9a',
#  'doi:10.17026/dans-zfe-bcar',
#  'doi:10.17026/dans-x3f-fpek',
#  'doi:10.17026/dans-xc4-jhj7',
#  'doi:10.17026/dans-z3b-3kg3',
#  'doi:10.17026/dans-xs6-pqaj',
#  'doi:10.17026/dans-2x8-mwp7',
#  'doi:10.17026/dans-xry-srqw',
#  'doi:10.17026/dans-23m-vsxe',
#  'doi:10.17026/dans-2cd-mh4w',
#  'doi:10.17026/dans-2a9-vjjf',
#  'doi:10.17026/dans-znd-rbts',
#  'doi:10.17026/dans-22f-7agv']

# %% [markdown]
# ### Random sample with no geospatial data

# %%
# Get 10 dois of datasets that don't have dansSpatialBoxNorth or dansSpatialPointX  
df_pub_no_spatial = df_pub[df_pub.dansSpatialBoxNorth.isna() & df_pub.dansSpatialPointX.isna()]
dois_no_spatial = df_pub_no_spatial.dsPersistentId.tolist()
random_dois_no_spatial = random.sample(dois_no_spatial, 100)

# %%
df_pub_no_spatial.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 98417 entries, 109 to 159269
# Data columns (total 13 columns):
#  #   Column                                                Non-Null Count  Dtype
# ---  ------                                                --------------  -----
#  0   dsPersistentId                                        98417 non-null  object
#  1   publicationStatus                                     98417 non-null  object
#  2   title                                                 98417 non-null  object
#  3   dsDescriptionValue                                    98417 non-null  object
#  4   dansSpatialPointX                                     0 non-null      object
#  5   dansSpatialPointY                                     0 non-null      object
#  6   dansSpatialPointScheme                                4 non-null      object
#  7   dansSpatialBoxNorth                                   0 non-null      object
#  8   dansSpatialBoxEast                                    0 non-null      object
#  9   dansSpatialBoxSouth                                   0 non-null      object
#  10  dansSpatialBoxWest                                    0 non-null      object
#  11  dansSpatialBoxScheme                                  2 non-null      object
#  12  dansSpatialCoverageControlleddansSpatialCoverageText  0 non-null      float64
# dtypes: float64(1), object(12)
# memory usage: 10.5+ MB

# %% [markdown]
# ### Query
#
# This query was used in an early stage of the project to save a sample of the metadata as a JSON to my disc. The Notebook [collect_metadata.ipynb](collect_metadata.ipynb) provides a way to store all metadata in a local instance of MongoDB.

# %%
import requests
import json
import time
# import pprint

def get_json(doi, prefix = 'geo'): 
    """
    Get JSON data of a dataset from the Archaeology Data Stations API.
    Wait for 1 second between requests to avoid overloading the server.

    :param doi: DOI of the dataset. Default is 'geo'
    :param prefix: Prefix of the resulting JSON file name
    :return: JSON data of the dataset 
    """

    url = f"https://archaeology.datastations.nl/api/datasets/export?exporter=OAI_ORE&persistentId={doi}"

    try:
        # Send a GET request to the URL
        response = requests.get(url)
        print(url)

        # Check if the request was successful
        response.raise_for_status()

        # Parse the JSON data
        data = response.json()

        # Optionally, save it to a file
        out_path = f'../jsons/{prefix}_{doi.replace('/', '%')}.json'


        with open(out_path, 'w') as json_file:
            json.dump(data, json_file, indent=4)

        print(f"JSON data has been saved to '{out_path}'.")
        # pprint.pprint(data) 

    except requests.exceptions.RequestException as e:
        print(f"An error occurred: {e}")

    # Wait for 1 second to avoid overloading the server
    wait_time = 1  # seconds
    time.sleep(wait_time)

# %%
for doi in random_dois_no_spatial:
    get_json(doi)
# Out:
# https://archaeology.datastations.nl/api/datasets/export?exporter=OAI_ORE&persistentId=doi:10.17026/dans-xwu-ac5u
# JSON data has been saved to '../jsons/nogeo_doi:10.17026%dans-xwu-ac5u.json'.
# https://archaeology.datastations.nl/api/datasets/export?exporter=OAI_ORE&persistentId=doi:10.17026/dans-xup-tcgu
# JSON data has been saved to '../jsons/nogeo_doi:10.17026%dans-xup-tcgu.json'.
# https://archaeology.datastations.nl/api/datasets/export?exporter=OAI_ORE&persistentId=doi:10.17026/dans-xye-hjvs
# JSON data has been saved to '../jsons/nogeo_doi:10.17026%dans-xye-hjvs.json'.
# https://archaeology.datastations.nl/api/datasets/export?exporter=OAI_ORE&persistentId=doi:10.17026/dans-z58-gde2
# JSON data has been saved to '../jsons/nogeo_doi:10.17026%dans-z58-gde2.json'.
# https://archaeology.datastations.nl/api/datasets/export?exporter=OAI_ORE&persistentId=doi:10.17026/dans-zw8-h5dj
# JSON data has been saved to '../jsons/nogeo_doi:10.17026%dans-zw8-h5dj.json'.
# https://archaeology.datastations.nl/api/datasets/export?exporter=OAI_ORE&persistentId=doi:10.17026/AR/1NZVBB
# JSON data has been saved to '../jsons/nogeo_doi:10.17026%AR%1NZVBB.json'.
# https://archaeology.datastations.nl/api/datasets/export?exporter=OAI_ORE&persistentId=doi:10.17026/dans-287-xe75
# JSON data has been saved to '../jsons/nogeo_doi:10.17026%dans-287-xe75.json'.
# https://archaeology.datastations.nl/api/datasets/export?exporter=OAI_ORE&persistentId=doi:10.17026/dans-xe2-utgq
# JSON data has been saved to '../jsons/nogeo_doi:10.17026%dans-xe2-utgq.json'.
# https://archaeology.datastations.nl/api/datasets/export?exporter=OAI_ORE&persistentId=doi:10.17026/dans-zqe-yacc
# JSON data has been saved to '../jsons/nogeo_doi:10.17026%dans-zqe-yacc.json'.
# https://archaeology.datastations.nl/api/datasets/export?exporter=OAI_ORE&persistentId=doi:10.17026/dans-x6b-vap9
# JSON data has been saved to '../jsons/nogeo_doi:10.17026%dans-x6b-vap9.json'.
# https://archaeology.datastations.nl/api/datasets/export?exporter=OAI_ORE&persistentId=doi:10.17026/dans-28p-8nab
# JSON data has been saved to '../jsons/nogeo_doi:10.17026%dans-28p-8nab.json'.
# https://archaeology.datastations.nl/api/datasets/export?exporter=OAI_ORE&persistentId=doi:10.17026/dans-288-479k
# JSON data has been saved to '../jsons/nogeo_doi:10.17026%dans-288-479k.json'.
# https://archaeology.datastations.nl/api/datasets/export?exporter=OAI_ORE&persistentId=doi:10.17026/dans-z2w-5vpf
# JSON data has been saved to '../jsons/nogeo_doi:10.17026%dans-z2w-5vpf.json'.
# https://archaeology.datastations.nl/api/datasets/export?exporter=OAI_ORE&persistentId=doi:10.17026/dans-zkc-sa9j
# JSON data has been saved to '../jsons/nogeo_doi:10.17026%dans-zkc-sa9j.json'.
# https://archaeology.datastations.nl/api/datasets/export?exporter=OAI_ORE&persistentId=doi:10.17026/dans-22e-5656
# JSON data has been saved to '../jsons/nogeo_doi:10.17026%dans-22e-5656.json'.
# https://archaeology.datastations.nl/api/datasets/export?exporter=OAI_ORE&persistentId=doi:10.17026/dans-xgs-gjtp
# JSON data has been saved to '../jsons/nogeo_doi:10.17026%dans-xgs-gjtp.json'.
# https://archaeology.datastations.nl/api/datasets/export?exporter=OAI_ORE&persistentId=doi:10.17026/dans-xam-abym
# JSON data has been saved to '../jsons/nogeo_doi:10.17026%dans-xam-abym.json'.
# https://archaeology.datastations.nl/api/datasets/export?exporter=OAI_ORE&persistentId=doi:10.17026/dans-xkv-hnc4
# JSON data has been saved to '../jsons/nogeo_doi:10.17026%dans-xkv-hnc4.json'.
# https://archaeology.datastations.nl/api/datasets/export?exporter=OAI_ORE&persistentId=doi:10.17026/dans-zab-arfw
# JSON data has been saved to '../jsons/nogeo_doi:10.17026%dans-zab-arfw.json'.
# https://archaeology.datastations.nl/api/datasets/export?exporter=OAI_ORE&persistentId=doi:10.17026/dans-xga-gfc3
# JSON data has been saved to '../jsons/nogeo_doi:10.17026%dans-xga-gfc3.json'.
# https://archaeology.datastations.nl/api/datasets/export?exporter=OAI_ORE&persistentId=doi:10.17026/dans-z6t-xfbd
# JSON data has been saved to '../jsons/nogeo_doi:10.17026%dans-z6t-xfbd.json'.
# https://archaeology.datastations.nl/api/datasets/export?exporter=OAI_ORE&persistentId=doi:10.17026/AR/SQVZ6X
# JSON data has been saved to '../jsons/nogeo_doi:10.17026%AR%SQVZ6X.json'.
# https://archaeology.datastations.nl/api/datasets/export?exporter=OAI_ORE&persistentId=doi:10.17026/dans-xy2-dsdh
# JSON data has been saved to '../jsons/nogeo_doi:10.17026%dans-xy2-dsdh.json'.
# https://archaeology.datastations.nl/api/datasets/export?exporter=OAI_ORE&persistentId=doi:10.17026/AR/NTLWTF
# JSON data has been saved to '../jsons/nogeo_doi:10.17026%AR%NTLWTF.json'.
# https://archaeology.datastations.nl/api/datasets/export?exporter=OAI_ORE&persistentId=doi:10.17026/dans-zak-q9xd
# JSON data has been saved to '../jsons/nogeo_doi:10.17026%dans-zak-q9xd.json'.
# https://archaeology.datastations.nl/api/datasets/export?exporter=OAI_ORE&persistentId=doi:10.17026/dans-xgf-v8dm
# JSON data has been saved to '../jsons/nogeo_doi:10.17026%dans-xgf-v8dm.json'.
# https://archaeology.datastations.nl/api/datasets/export?exporter=OAI_ORE&persistentId=doi:10.17026/dans-xpg-6yuy
# JSON data has been saved to '../jsons/nogeo_doi:10.17026%dans-xpg-6yuy.json'.
# https://archaeology.datastations.nl/api/datasets/export?exporter=OAI_ORE&persistentId=doi:10.17026/AR/ETIOJX
# JSON data has been saved to '../jsons/nogeo_doi:10.17026%AR%ETIOJX.json'.
# https://archaeology.datastations.nl/api/datasets/export?exporter=OAI_ORE&persistentId=doi:10.17026/dans-xk9-m35m
# JSON data has been saved to '../jsons/nogeo_doi:10.17026%dans-xk9-m35m.json'.
# https://archaeology.datastations.nl/api/datasets/export?exporter=OAI_ORE&persistentId=doi:10.17026/AR/WKFLMV
# JSON data has been saved to '../jsons/nogeo_doi:10.17026%AR%WKFLMV.json'.
# https://archaeology.datastations.nl/api/datasets/export?exporter=OAI_ORE&persistentId=doi:10.17026/dans-zwm-useg
# JSON data has been saved to '../jsons/nogeo_doi:10.17026%dans-zwm-useg.json'.
# https://archaeology.datastations.nl/api/datasets/export?exporter=OAI_ORE&persistentId=doi:10.17026/dans-x7g-esex
# JSON data has been saved to '../jsons/nogeo_doi:10.17026%dans-x7g-esex.json'.
# https://archaeology.datastations.nl/api/datasets/export?exporter=OAI_ORE&persistentId=doi:10.17026/dans-zm7-7mnt
# JSON data has been saved to '../jsons/nogeo_doi:10.17026%dans-zm7-7mnt.json'.
# https://archaeology.datastations.nl/api/datasets/export?exporter=OAI_ORE&persistentId=doi:10.17026/dans-xch-6yzx
# JSON data has been saved to '../jsons/nogeo_doi:10.17026%dans-xch-6yzx.json'.
# https://archaeology.datastations.nl/api/datasets/export?exporter=OAI_ORE&persistentId=doi:10.17026/dans-28j-jxw2
# JSON data has been saved to '../jsons/nogeo_doi:10.17026%dans-28j-jxw2.json'.
# https://archaeology.datastations.nl/api/datasets/export?exporter=OAI_ORE&persistentId=doi:10.17026/dans-z68-wy9h
# JSON data has been saved to '../jsons/nogeo_doi:10.17026%dans-z68-wy9h.json'.
# https://archaeology.datastations.nl/api/datasets/export?exporter=OAI_ORE&persistentId=doi:10.17026/dans-26n-8efy
# JSON data has been saved to '../jsons/nogeo_doi:10.17026%dans-26n-8efy.json'.
# https://archaeology.datastations.nl/api/datasets/export?exporter=OAI_ORE&persistentId=doi:10.17026/dans-xy2-pqad
# JSON data has been saved to '../jsons/nogeo_doi:10.17026%dans-xy2-pqad.json'.
# https://archaeology.datastations.nl/api/datasets/export?exporter=OAI_ORE&persistentId=doi:10.17026/dans-xvx-xbbc
# JSON data has been saved to '../jsons/nogeo_doi:10.17026%dans-xvx-xbbc.json'.
# https://archaeology.datastations.nl/api/datasets/export?exporter=OAI_ORE&persistentId=doi:10.17026/dans-xcj-zcxv
# JSON data has been saved to '../jsons/nogeo_doi:10.17026%dans-xcj-zcxv.json'.
# https://archaeology.datastations.nl/api/datasets/export?exporter=OAI_ORE&persistentId=doi:10.17026/dans-xvj-keh9
# JSON data has been saved to '../jsons/nogeo_doi:10.17026%dans-xvj-keh9.json'.
# https://archaeology.datastations.nl/api/datasets/export?exporter=OAI_ORE&persistentId=doi:10.17026/dans-xvg-svwm
# JSON data has been saved to '../jsons/nogeo_doi:10.17026%dans-xvg-svwm.json'.
# https://archaeology.datastations.nl/api/datasets/export?exporter=OAI_ORE&persistentId=doi:10.17026/dans-xub-yrvk
# JSON data has been saved to '../jsons/nogeo_doi:10.17026%dans-xub-yrvk.json'.
# https://archaeology.datastations.nl/api/datasets/export?exporter=OAI_ORE&persistentId=doi:10.17026/dans-286-dy7s
# JSON data has been saved to '../jsons/nogeo_doi:10.17026%dans-286-dy7s.json'.
# https://archaeology.datastations.nl/api/datasets/export?exporter=OAI_ORE&persistentId=doi:10.17026/dans-z3a-gxbd
# JSON data has been saved to '../jsons/nogeo_doi:10.17026%dans-z3a-gxbd.json'.
# https://archaeology.datastations.nl/api/datasets/export?exporter=OAI_ORE&persistentId=doi:10.17026/dans-xf3-zg3w
# JSON data has been saved to '../jsons/nogeo_doi:10.17026%dans-xf3-zg3w.json'.
# https://archaeology.datastations.nl/api/datasets/export?exporter=OAI_ORE&persistentId=doi:10.17026/dans-2cf-dc26
# JSON data has been saved to '../jsons/nogeo_doi:10.17026%dans-2cf-dc26.json'.
# https://archaeology.datastations.nl/api/datasets/export?exporter=OAI_ORE&persistentId=doi:10.17026/dans-zzg-en4s
# JSON data has been saved to '../jsons/nogeo_doi:10.17026%dans-zzg-en4s.json'.
# https://archaeology.datastations.nl/api/datasets/export?exporter=OAI_ORE&persistentId=doi:10.17026/dans-zvx-3mcc
# JSON data has been saved to '../jsons/nogeo_doi:10.17026%dans-zvx-3mcc.json'.
# https://archaeology.datastations.nl/api/datasets/export?exporter=OAI_ORE&persistentId=doi:10.17026/dans-zt7-avm9
# JSON data has been saved to '../jsons/nogeo_doi:10.17026%dans-zt7-avm9.json'.
# https://archaeology.datastations.nl/api/datasets/export?exporter=OAI_ORE&persistentId=doi:10.17026/AR/ECRXQY
# JSON data has been saved to '../jsons/nogeo_doi:10.17026%AR%ECRXQY.json'.
# https://archaeology.datastations.nl/api/datasets/export?exporter=OAI_ORE&persistentId=doi:10.17026/dans-za4-s88t
# JSON data has been saved to '../jsons/nogeo_doi:10.17026%dans-za4-s88t.json'.
# https://archaeology.datastations.nl/api/datasets/export?exporter=OAI_ORE&persistentId=doi:10.17026/dans-2c7-2hvp
# JSON data has been saved to '../jsons/nogeo_doi:10.17026%dans-2c7-2hvp.json'.
# https://archaeology.datastations.nl/api/datasets/export?exporter=OAI_ORE&persistentId=doi:10.17026/dans-2bf-4kmj
# JSON data has been saved to '../jsons/nogeo_doi:10.17026%dans-2bf-4kmj.json'.
# https://archaeology.datastations.nl/api/datasets/export?exporter=OAI_ORE&persistentId=doi:10.17026/dans-24b-hhmb
# JSON data has been saved to '../jsons/nogeo_doi:10.17026%dans-24b-hhmb.json'.
# https://archaeology.datastations.nl/api/datasets/export?exporter=OAI_ORE&persistentId=doi:10.17026/dans-xqj-t3cg
# JSON data has been saved to '../jsons/nogeo_doi:10.17026%dans-xqj-t3cg.json'.
# https://archaeology.datastations.nl/api/datasets/export?exporter=OAI_ORE&persistentId=doi:10.17026/dans-xpy-e77k
# JSON data has been saved to '../jsons/nogeo_doi:10.17026%dans-xpy-e77k.json'.
# https://archaeology.datastations.nl/api/datasets/export?exporter=OAI_ORE&persistentId=doi:10.17026/dans-xjn-h5z8
# JSON data has been saved to '../jsons/nogeo_doi:10.17026%dans-xjn-h5z8.json'.
# https://archaeology.datastations.nl/api/datasets/export?exporter=OAI_ORE&persistentId=doi:10.17026/dans-xf3-bkzk
# JSON data has been saved to '../jsons/nogeo_doi:10.17026%dans-xf3-bkzk.json'.
# https://archaeology.datastations.nl/api/datasets/export?exporter=OAI_ORE&persistentId=doi:10.17026/dans-xmh-nt5c
# JSON data has been saved to '../jsons/nogeo_doi:10.17026%dans-xmh-nt5c.json'.
# https://archaeology.datastations.nl/api/datasets/export?exporter=OAI_ORE&persistentId=doi:10.17026/dans-x8n-dfak
# JSON data has been saved to '../jsons/nogeo_doi:10.17026%dans-x8n-dfak.json'.
# https://archaeology.datastations.nl/api/datasets/export?exporter=OAI_ORE&persistentId=doi:10.17026/AR/Y9GXUQ
# JSON data has been saved to '../jsons/nogeo_doi:10.17026%AR%Y9GXUQ.json'.
# https://archaeology.datastations.nl/api/datasets/export?exporter=OAI_ORE&persistentId=doi:10.17026/dans-zdx-tz2j
# JSON data has been saved to '../jsons/nogeo_doi:10.17026%dans-zdx-tz2j.json'.
# https://archaeology.datastations.nl/api/datasets/export?exporter=OAI_ORE&persistentId=doi:10.17026/dans-267-japs
# JSON data has been saved to '../jsons/nogeo_doi:10.17026%dans-267-japs.json'.
# https://archaeology.datastations.nl/api/datasets/export?exporter=OAI_ORE&persistentId=doi:10.17026/dans-xgy-d8tz
# JSON data has been saved to '../jsons/nogeo_doi:10.17026%dans-xgy-d8tz.json'.
# https://archaeology.datastations.nl/api/datasets/export?exporter=OAI_ORE&persistentId=doi:10.17026/dans-xxu-6dzy
# JSON data has been saved to '../jsons/nogeo_doi:10.17026%dans-xxu-6dzy.json'.
# https://archaeology.datastations.nl/api/datasets/export?exporter=OAI_ORE&persistentId=doi:10.17026/dans-x9a-yxzd
# JSON data has been saved to '../jsons/nogeo_doi:10.17026%dans-x9a-yxzd.json'.
# https://archaeology.datastations.nl/api/datasets/export?exporter=OAI_ORE&persistentId=doi:10.17026/dans-2aa-7sg4
# JSON data has been saved to '../jsons/nogeo_doi:10.17026%dans-2aa-7sg4.json'.
# https://archaeology.datastations.nl/api/datasets/export?exporter=OAI_ORE&persistentId=doi:10.17026/dans-zh2-6ube
# JSON data has been saved to '../jsons/nogeo_doi:10.17026%dans-zh2-6ube.json'.
# https://archaeology.datastations.nl/api/datasets/export?exporter=OAI_ORE&persistentId=doi:10.17026/dans-x85-r3ux
# JSON data has been saved to '../jsons/nogeo_doi:10.17026%dans-x85-r3ux.json'.
# https://archaeology.datastations.nl/api/datasets/export?exporter=OAI_ORE&persistentId=doi:10.17026/dans-x9e-srvu
# JSON data has been saved to '../jsons/nogeo_doi:10.17026%dans-x9e-srvu.json'.
# https://archaeology.datastations.nl/api/datasets/export?exporter=OAI_ORE&persistentId=doi:10.17026/dans-zby-fwr8
# JSON data has been saved to '../jsons/nogeo_doi:10.17026%dans-zby-fwr8.json'.
# https://archaeology.datastations.nl/api/datasets/export?exporter=OAI_ORE&persistentId=doi:10.17026/AR/FSDUGX
# JSON data has been saved to '../jsons/nogeo_doi:10.17026%AR%FSDUGX.json'.
# https://archaeology.datastations.nl/api/datasets/export?exporter=OAI_ORE&persistentId=doi:10.17026/dans-266-fe5a
# JSON data has been saved to '../jsons/nogeo_doi:10.17026%dans-266-fe5a.json'.
# https://archaeology.datastations.nl/api/datasets/export?exporter=OAI_ORE&persistentId=doi:10.17026/dans-zdc-usah
# JSON data has been saved to '../jsons/nogeo_doi:10.17026%dans-zdc-usah.json'.
# https://archaeology.datastations.nl/api/datasets/export?exporter=OAI_ORE&persistentId=doi:10.17026/AR/WIPZRT
# JSON data has been saved to '../jsons/nogeo_doi:10.17026%AR%WIPZRT.json'.
# https://archaeology.datastations.nl/api/datasets/export?exporter=OAI_ORE&persistentId=doi:10.17026/dans-z2w-prv6
# JSON data has been saved to '../jsons/nogeo_doi:10.17026%dans-z2w-prv6.json'.
# https://archaeology.datastations.nl/api/datasets/export?exporter=OAI_ORE&persistentId=doi:10.17026/dans-xab-ppz6
# JSON data has been saved to '../jsons/nogeo_doi:10.17026%dans-xab-ppz6.json'.
# https://archaeology.datastations.nl/api/datasets/export?exporter=OAI_ORE&persistentId=doi:10.17026/dans-x69-kua4
# JSON data has been saved to '../jsons/nogeo_doi:10.17026%dans-x69-kua4.json'.
# https://archaeology.datastations.nl/api/datasets/export?exporter=OAI_ORE&persistentId=doi:10.17026/dans-zzh-3469
# JSON data has been saved to '../jsons/nogeo_doi:10.17026%dans-zzh-3469.json'.
# https://archaeology.datastations.nl/api/datasets/export?exporter=OAI_ORE&persistentId=doi:10.17026/dans-xwg-7ykh
# JSON data has been saved to '../jsons/nogeo_doi:10.17026%dans-xwg-7ykh.json'.
# https://archaeology.datastations.nl/api/datasets/export?exporter=OAI_ORE&persistentId=doi:10.17026/dans-zze-etna
# JSON data has been saved to '../jsons/nogeo_doi:10.17026%dans-zze-etna.json'.
# https://archaeology.datastations.nl/api/datasets/export?exporter=OAI_ORE&persistentId=doi:10.17026/AR/ZT2HQJ
# JSON data has been saved to '../jsons/nogeo_doi:10.17026%AR%ZT2HQJ.json'.
# https://archaeology.datastations.nl/api/datasets/export?exporter=OAI_ORE&persistentId=doi:10.17026/dans-xqs-hxzk
# JSON data has been saved to '../jsons/nogeo_doi:10.17026%dans-xqs-hxzk.json'.
# https://archaeology.datastations.nl/api/datasets/export?exporter=OAI_ORE&persistentId=doi:10.17026/dans-zh5-2fhz
# JSON data has been saved to '../jsons/nogeo_doi:10.17026%dans-zh5-2fhz.json'.
# https://archaeology.datastations.nl/api/datasets/export?exporter=OAI_ORE&persistentId=doi:10.17026/AR/2KODWE
# JSON data has been saved to '../jsons/nogeo_doi:10.17026%AR%2KODWE.json'.
# https://archaeology.datastations.nl/api/datasets/export?exporter=OAI_ORE&persistentId=doi:10.17026/dans-x53-8jyt
# JSON data has been saved to '../jsons/nogeo_doi:10.17026%dans-x53-8jyt.json'.
# https://archaeology.datastations.nl/api/datasets/export?exporter=OAI_ORE&persistentId=doi:10.17026/dans-25h-m25t
# JSON data has been saved to '../jsons/nogeo_doi:10.17026%dans-25h-m25t.json'.
# https://archaeology.datastations.nl/api/datasets/export?exporter=OAI_ORE&persistentId=doi:10.17026/dans-zy6-8bpk
# JSON data has been saved to '../jsons/nogeo_doi:10.17026%dans-zy6-8bpk.json'.
# https://archaeology.datastations.nl/api/datasets/export?exporter=OAI_ORE&persistentId=doi:10.17026/AR/NAO20O
# JSON data has been saved to '../jsons/nogeo_doi:10.17026%AR%NAO20O.json'.
# https://archaeology.datastations.nl/api/datasets/export?exporter=OAI_ORE&persistentId=doi:10.17026/dans-xfs-smye
# JSON data has been saved to '../jsons/nogeo_doi:10.17026%dans-xfs-smye.json'.
# https://archaeology.datastations.nl/api/datasets/export?exporter=OAI_ORE&persistentId=doi:10.17026/dans-zfq-qrkz
# JSON data has been saved to '../jsons/nogeo_doi:10.17026%dans-zfq-qrkz.json'.
# https://archaeology.datastations.nl/api/datasets/export?exporter=OAI_ORE&persistentId=doi:10.17026/dans-zuv-h4ar
# JSON data has been saved to '../jsons/nogeo_doi:10.17026%dans-zuv-h4ar.json'.
# https://archaeology.datastations.nl/api/datasets/export?exporter=OAI_ORE&persistentId=doi:10.17026/dans-27p-bw5d
# JSON data has been saved to '../jsons/nogeo_doi:10.17026%dans-27p-bw5d.json'.
# https://archaeology.datastations.nl/api/datasets/export?exporter=OAI_ORE&persistentId=doi:10.17026/dans-zf4-f9y7
# JSON data has been saved to '../jsons/nogeo_doi:10.17026%dans-zf4-f9y7.json'.
# https://archaeology.datastations.nl/api/datasets/export?exporter=OAI_ORE&persistentId=doi:10.17026/dans-2zf-bzfa
# JSON data has been saved to '../jsons/nogeo_doi:10.17026%dans-2zf-bzfa.json'.
# https://archaeology.datastations.nl/api/datasets/export?exporter=OAI_ORE&persistentId=doi:10.17026/dans-z5m-ktc9
# JSON data has been saved to '../jsons/nogeo_doi:10.17026%dans-z5m-ktc9.json'.
# https://archaeology.datastations.nl/api/datasets/export?exporter=OAI_ORE&persistentId=doi:10.17026/dans-2bn-wamz
# JSON data has been saved to '../jsons/nogeo_doi:10.17026%dans-2bn-wamz.json'.
# https://archaeology.datastations.nl/api/datasets/export?exporter=OAI_ORE&persistentId=doi:10.17026/AR/8LJ3YG
# JSON data has been saved to '../jsons/nogeo_doi:10.17026%AR%8LJ3YG.json'.
# https://archaeology.datastations.nl/api/datasets/export?exporter=OAI_ORE&persistentId=doi:10.17026/dans-2bx-kp22
# JSON data has been saved to '../jsons/nogeo_doi:10.17026%dans-2bx-kp22.json'.
