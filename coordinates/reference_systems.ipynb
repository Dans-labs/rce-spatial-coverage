# %% [markdown]
# # Explore coordinate reference systems (CRS)
# - A CRS defines a location on Earth. It tells the computer how to map coordinates or geometric shapes to places on the Earth.
# - A commonly used *geographic coordinate system* is the WGS84, and it models the earth as a three-dimensional sphere and uses angles to specify locations. It uses the latitude-longitude projection. It's the default system for GPS.
# - A *projected coordinate system* models the Earth as a two-dimensional plane with locations specified by x and y coordinates.
# - There are different approaches to both systems, which can make it complicated to map different systems to the same map.

# %% [markdown]
# ### Re-projecting
# How well does the [GeoPandas](https://geopandas.org/en/stable/docs/user_guide/projections.html) command `GeoDataFrame.to_crs()` do on harmonizing the projections?

# %% [markdown]
# ### Dataverse Geospatial search
# - see [here](https://guides.dataverse.org/en/latest/user/find-use-data.html#geospatial-search): requires the geographic bounding boxes (Geospatial Metadata block) to be filled in.

# %% [markdown]
# ### What are the current CRS?

# %%
import pandas as pd

# %%
df = pd.read_csv('../data/archaeology_metadata.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158254 entries, 0 to 158253
# Data columns (total 13 columns):
#  #   Column                                                Non-Null Count   Dtype
# ---  ------                                                --------------   -----
#  0   dsPersistentId                                        158254 non-null  object
#  1   publicationStatus                                     158254 non-null  object
#  2   title                                                 158254 non-null  object
#  3   dsDescriptionValue                                    158254 non-null  object
#  4   dansSpatialPointX                                     56479 non-null   object
#  5   dansSpatialPointY                                     56479 non-null   object
#  6   dansSpatialPointScheme                                56304 non-null   object
#  7   dansSpatialBoxNorth                                   4432 non-null    object
#  8   dansSpatialBoxEast                                    4430 non-null    object
#  9   dansSpatialBoxSouth                                   4426 non-null    object
#  10  dansSpatialBoxWest                                    4424 non-null    object
#  11  dansSpatialBoxScheme                                  4438 non-null    object
#  12  dansSpatialCoverageControlleddansSpatialCoverageText  0 non-null       float64
# dtypes: float64(1), object(12)
# memory usage: 15.7+ MB

# %%
# Inspect spatial points 
df.dansSpatialPointX.describe()
# Out:
# count      56479
# unique     45942
# top       193000
# freq          13
# Name: dansSpatialPointX, dtype: object

# %%
df.dansSpatialPointY.describe()
# Out:
# count        56479
# unique       45838
# top       52.29687
# freq            12
# Name: dansSpatialPointY, dtype: object

# %%
# TO DO: combine geoinfo into one variable 
df['coordinates'] = df.apply(lambda row: f"{row['dansSpatialPointX']},{row['dansSpatialPointY']},{row['dansSpatialPointScheme']}", axis=1)

# %%
df
# Out:
#                     dsPersistentId publicationStatus  \
# 0       doi:10.17026/dans-zrj-unr7         Published
# 1       doi:10.17026/dans-299-9dpm         Published
# 2       doi:10.17026/dans-zqy-ymw8         Published
# 3       doi:10.17026/dans-z8d-9c6h         Published
# 4       doi:10.17026/dans-x9v-j3qu         Published
# ...                            ...               ...
# 158249      doi:10.17026/AR/H4IDSE         Published
# 158250      doi:10.17026/AR/19BCUB         Published
# 158251      doi:10.17026/AR/QXOI5Q         Published
# 158252      doi:10.17026/AR/QHHAGE         Published
# 158253      doi:10.17026/AR/FBKZM2         Published
#
#                                                     title  \
# 0                        Gouda Kattensingel Booronderzoek
# 1                                      Zandwingebied Q10R
# 2        Kerkrade Landgraaf buffer Kraanweg Booronderzoek
# 3       Archeologisch Bureauonderzoek en Inventarisere...
# 4       Archeologisch Bureauonderzoek Reconstructie Si...
# ...                                                   ...
# 158249  IVO-karterende fase zonnepark Groot Roodehaan,...
# 158250  Gemeente Moerdijk plangebied de Kogelvangers t...
# 158251  Archeologisch bureauonderzoek perceel tussen K...
# 158252  Archeologisch bureauonderzoek Den Ilp 53a te D...
# 158253  Archeologisch bureauonderzoek Oorgat 6-6a te E...
#
#                                        dsDescriptionValue  \
# 0       ADC ArcheoProjecten heeft in januari 2017 een ...
# 1       In opdracht van- en in samenwerking met Rijksw...
# 2       ADC ArcheoProjecten heeft in december 2016 een...
# 3       In het kader van de vergunningverlening ten be...
# 4       In het kader van de vergunningverlening ten be...
# ...                                                   ...
# 158249  Laagland Archeologie heeft in april 2021 een k...
# 158250  Op basis van het bureauonderzoek geldt er voor...
# 158251  In november 2021 is een archeologisch bureauon...
# 158252  In november 2021 is in opdracht van een partic...
# 158253  In oktober 2021 is een archeologisch bureauond...
#
#                          dansSpatialPointX  \
# 0                                   108240
# 1                                    77230
# 2                                   203505
# 3                                    95873
# 4                     197332,197337,197185
# ...                                    ...
# 158249  238853,238979,239404,239437,239175
# 158250                                 NaN
# 158251                             101.391
# 158252                             122.592
# 158253                             133.371
#
#                          dansSpatialPointY  \
# 0                                   447370
# 1                                   490214
# 2                                   324100
# 3                                   421799
# 4                     356659,356100,355712
# ...                                    ...
# 158249  579376,579083,579242,579530,579532
# 158250                                 NaN
# 158251                             497.243
# 158252                             495.815
# 158253                             503.251
#
#                              dansSpatialPointScheme dansSpatialBoxNorth  \
# 0                                        RD (in m.)                 NaN
# 1                                        RD (in m.)                 NaN
# 2                                        RD (in m.)                 NaN
# 3                                        RD (in m.)                 NaN
# 4                  RD (in m.),RD (in m.),RD (in m.)                 NaN
# ...                                             ...                 ...
# 158249  RD (in m.),RD (in m.),RD (in m.),RD (in m.)                 NaN
# 158250                                          NaN              411813
# 158251                                   RD (in m.)                 NaN
# 158252                                          NaN                 NaN
# 158253                                   RD (in m.)                 NaN
#
#        dansSpatialBoxEast dansSpatialBoxSouth dansSpatialBoxWest  \
# 0                     NaN                 NaN                NaN
# 1                     NaN                 NaN                NaN
# 2                     NaN                 NaN                NaN
# 3                     NaN                 NaN                NaN
# 4                     NaN                 NaN                NaN
# ...                   ...                 ...                ...
# 158249                NaN                 NaN                NaN
# 158250              90282              411486              89850
# 158251                NaN                 NaN                NaN
# 158252                NaN                 NaN                NaN
# 158253                NaN                 NaN                NaN
#
#        dansSpatialBoxScheme  \
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
# ...                     ...
# 158249                  NaN
# 158250           RD (in m.)
# 158251                  NaN
# 158252                  NaN
# 158253                  NaN
#
#         dansSpatialCoverageControlleddansSpatialCoverageText  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 158249                                                NaN
# 158250                                                NaN
# 158251                                                NaN
# 158252                                                NaN
# 158253                                                NaN
#
#                                               coordinates
# 0                                108240,447370,RD (in m.)
# 1                                 77230,490214,RD (in m.)
# 2                                203505,324100,RD (in m.)
# 3                                 95873,421799,RD (in m.)
# 4       197332,197337,197185,356659,356100,355712,RD (...
# ...                                                   ...
# 158249  238853,238979,239404,239437,239175,579376,5790...
# 158250                                        nan,nan,nan
# 158251                         101.391,497.243,RD (in m.)
# 158252                                122.592,495.815,nan
# 158253                         133.371,503.251,RD (in m.)
#
# [158254 rows x 14 columns]

# %%
status = df.coordinates.value_counts()
print(status)
# Out:
# coordinates
# nan,nan,nan                                      101769
# 5.16721,52.29687,longitude/latitude (degrees)        12
# 5.45851,51.99553,longitude/latitude (degrees)        10
# 189397,415792,RD (in m.)                              8
# 96280,423770,RD (in m.)                               8
#                                                   ...
# 105789,432056,RD (in m.)                              1
# 185595,432967,RD (in m.)                              1
# 143935,423750,RD (in m.)                              1
# 180466,474621,RD (in m.)                              1
# 203505,324100,RD (in m.)                              1
# Name: count, Length: 53279, dtype: int64

# %%
# Get the length of the first entry in the 'coordinates' column
first_entry_length = len(df['coordinates'].iloc[0])

# Select rows where the length of the 'coordinates' value is longer than the first entry
selected_rows = df[df['coordinates'].apply(len) > first_entry_length*1.8]

# Display the selected rows
selected_rows.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5071 entries, 4 to 158249
# Data columns (total 14 columns):
#  #   Column                                                Non-Null Count  Dtype
# ---  ------                                                --------------  -----
#  0   dsPersistentId                                        5071 non-null   object
#  1   publicationStatus                                     5071 non-null   object
#  2   title                                                 5071 non-null   object
#  3   dsDescriptionValue                                    5071 non-null   object
#  4   dansSpatialPointX                                     5070 non-null   object
#  5   dansSpatialPointY                                     5070 non-null   object
#  6   dansSpatialPointScheme                                5071 non-null   object
#  7   dansSpatialBoxNorth                                   47 non-null     object
#  8   dansSpatialBoxEast                                    47 non-null     object
#  9   dansSpatialBoxSouth                                   47 non-null     object
#  10  dansSpatialBoxWest                                    47 non-null     object
#  11  dansSpatialBoxScheme                                  48 non-null     object
#  12  dansSpatialCoverageControlleddansSpatialCoverageText  0 non-null      float64
#  13  coordinates                                           5071 non-null   object
# dtypes: float64(1), object(13)
# memory usage: 594.3+ KB

# %%
df.dsDescriptionValue[9]
# Out:
# 'In opdracht van Geofox-Lexmond bv heeft ArGeoBoor een archeologisch bureauonderzoek uitgevoerd voor een locatie aan de Wollenfoppeweg 109 te Zevenhuizen (Gemeente Zuidplas). Het voornemen is om een bestaande woning te verbouwen. Hierbij wordt aan de zuidzijde van de woning een souterrain (60 m2) met terras gerealiseerd met een totale oppervlakte van 112 m2 met een diepte van circa 80 cm-mv. Hierbij worden de vrijstellingsgrenzen\\, zoals geformuleerd in het archeologisch beleid van de gemeente Zuidplas net overschreden. Het plangebied is gelegen op een oeverwal waarvan de top waarschijnlijk ondieper dan 120 cm – mv ligt. Er worden resten verwacht uit met name het mesolithicum\\, en in mindere mate het neolithicum. Daarnaast kunnen waarden uit de vroege nieuwe tijd worden verwacht. Resten uit andere perioden worden niet verwacht. In de loop van het neolithicum werd het plangebied waarschijnlijk te nat voor bewoning. Er ontstond veen dat het gebied tot aan de ontginning van het gebied vrijwel onbewoonbaar en onbegaanbaar maakte. Blijkens de gemeentelijke beleidskaart heeft er in het verleden bodemverstoring plaatsgevonden\\, maar het is niet bekend tot hoe diep. Evenzo is de diepteligging van eventuele archeologische lagen niet precies bekend. Gezien de geringe omvang van het plangebied en de reeds aanwezige bodemverstoring ter plaatse is de kans op het aantreffen van archeologische waarden klein. Het plangebied wordt daarom niet behoudenswaardig geacht. Geadviseerd wordt geen nader archeologisch onderzoek uit te voeren en het plangebied daarmee vrij te geven. Dit selectieadvies dient te worden voorgelegd aan de bevoegde overheid in dit geval de Gemeente Zuidplas. Deze zullen op basis van de aangeleverde gegevens een selectiebesluit nemen over deze aanbeveling. ArGeoBoor wijst erop dat men bij bodem verstorende activiteiten verplicht is om eventuele vondsten en grondsporen direct te melden bij de Minister van OCW conform artikel 53 van de Monumentenwet uit 1988. In dit geval wordt aangeraden om onmiddellijk contact op te nemen met de Gemeente Zuidplas.'

# %%
coordinates = df['coordinates'].tolist()

for idx, point in enumerate(coordinates[:1000]):
    print(f"{idx}: {point}")
    print()
# Out:
# 0: 108240,447370,RD (in m.)
#
# 1: 77230,490214,RD (in m.)
#
# 2: 203505,324100,RD (in m.)
#
# 3: 95873,421799,RD (in m.)
#
# 4: 197332,197337,197185,356659,356100,355712,RD (in m.),RD (in m.),RD (in m.)
#
# 5: 252880,246560,469005,466480,RD (in m.),RD (in m.)
#
# 6: 147525,405110,RD (in m.)
#
# 7: 180466,474621,RD (in m.)
#
# 8: 104419,104755,387291,385751,RD (in m.),RD (in m.)
#
# 9: 97200,442880,RD (in m.)
#
# 10: 46155,383439,RD (in m.)
#
# 11: nan,nan,nan
#
# 12: nan,nan,nan
#
# 13: nan,nan,nan
#
# 14: 166158,380715,RD (in m.)
#
# 15: 235216,559339,RD (in m.)
#
# 16: 82814,82813,378297,378297,RD (in m.),RD (in m.)
#
# 17: nan,nan,nan
#
# 18: 60645,385538,RD (in m.)
#
# 19: 148583,434102,RD (in m.)
#
# 20: 77961,450423,RD (in m.)
#
# 21: 165425,151900,509415,490500,RD (in m.),RD (in m.)
#
# 22: 239090,555588,RD (in m.)
#
# 23: 193305,579699,RD (in m.)
#
# 24: 63710,381960,RD (in m.)
#
# 25: 180500,366393,RD (in m.)
#
# 26: 197650,355880,RD (in m.)
#
# 27: 184810,567618,RD (in m.)
#
# 28: 253932,561052,RD (in m.)
#
# 29: 234560,581512,RD (in m.)
#
# 30: 105741,507353,RD (in m.)
#
# 31: 15620,370604,RD (in m.)
#
# 32: 196910,433519,RD (in m.)
#
# 33: 49410,391676,RD (in m.)
#
# 34: 111989,485361,RD (in m.)
#
# 35: 167683,167719,368230,368159,RD (in m.),RD (in m.)
#
# 36: 231200,592188,RD (in m.)
#
# 37: 270724,270533,549481,549756,RD (in m.),RD (in m.)
#
# 38: 233799,555978,RD (in m.)
#
# 39: 69164,436163,RD (in m.)
#
# 40: 103764,400062,RD (in m.)
#
# 41: 228127,593512,RD (in m.)
#
# 42: 194731,196401,536433,536414,RD (in m.),RD (in m.)
#
# 43: 75385,449182,RD (in m.)
#
# 44: 109920,434560,RD (in m.)
#
# 45: 72162,71152,428753,429882,RD (in m.),RD (in m.)
#
# 46: 148200,432800,RD (in m.)
#
# 47: 229175,436525,RD (in m.)
#
# 48: 207210,527480,RD (in m.)
#
# 49: 93880,464815,RD (in m.)
#
# 50: 160854,415912,RD (in m.)
#
# 51: 230652,584180,RD (in m.)
#
# 52: 144350,417380,RD (in m.)
#
# 53: 121778,424507,RD (in m.)
#
# 54: 256702,533070,RD (in m.)
#
# 55: 104337,469715,RD (in m.)
#
# 56: 91910,473470,RD (in m.)
#
# 57: 175848,175866,175791,175904,175755,421989,422022,422009,422039,422150,RD (in m.),RD (in m.),RD (in m.),RD (in m.),RD (in m.)
#
# 58: 169057,169473,473936,473727,RD (in m.),RD (in m.)
#
# 59: 201709,526828,RD (in m.)
#
# 60: 194270,596429,RD (in m.)
#
# 61: 225142,592116,RD (in m.)
#
# 62: 201109,364297,RD (in m.)
#
# 63: 103111,426190,RD (in m.)
#
# 64: 141475,471480,RD (in m.)
#
# 65: 95785,95575,472970,472865,RD (in m.),RD (in m.)
#
# 66: 195226,412813,RD (in m.)
#
# 67: 157741,415914,RD (in m.)
#
# 68: 76877,76917,76934,76903,76919,76910,426743,426792,426778,426741,426727,426716,RD (in m.),RD (in m.),RD (in m.),RD (in m.),RD (in m.),RD (in m.)
#
# 69: 172195,560092,RD (in m.)
#
# 70: 127709,409807,RD (in m.)
#
# 71: 244888,245243,520475,521129,RD (in m.),RD (in m.)
#
# 72: 157618,453329,RD (in m.)
#
# 73: 61906,62227,62343,389694,389475,389850,RD (in m.),RD (in m.),RD (in m.)
#
# 74: 103738,502822,RD (in m.)
#
# 75: 123640,449390,RD (in m.)
#
# 76: 72050,449390,RD (in m.)
#
# 77: nan,nan,nan
#
# 78: 159125,376955,RD (in m.)
#
# 79: 193685,468990,RD (in m.)
#
# 80: 200916,358260,RD (in m.)
#
# 81: 82637,448094,RD (in m.)
#
# 82: 50827,390847,RD (in m.)
#
# 83: 214156,459586,RD (in m.)
#
# 84: 131021,407062,RD (in m.)
#
# 85: 160736,372302,RD (in m.)
#
# 86: 141705,432850,RD (in m.)
#
# 87: 152392,383935,RD (in m.)
#
# 88: 68402,68318,68355,68282,427439,426941,427445,426955,RD (in m.),RD (in m.),RD (in m.),RD (in m.)
#
# 89: 116470,464380,RD (in m.)
#
# 90: 124880,525900,RD (in m.)
#
# 91: 189791,411327,RD (in m.)
#
# 92: 201173,442315,RD (in m.)
#
# 93: 72331,392871,RD (in m.)
#
# 94: nan,nan,nan
#
# 95: 187718,420338,RD (in m.)
#
# 96: 87192,437131,RD (in m.)
#
# 97: 134142,395915,RD (in m.)
#
# 98: 159058,390316,RD (in m.)
#
# 99: 177264,415678,RD (in m.)
#
# 100: nan,nan,nan
#
# 101: 235990,472246,RD (in m.)
#
# 102: 110100,399638,RD (in m.)
#
# 103: 121670,428990,RD (in m.)
#
# 104: 158631,424185,RD (in m.)
#
# 105: nan,nan,nan
#
# 106: nan,nan,nan
#
# 107: 46777,46697,363111,362999,RD (in m.),RD (in m.)
#
# 108: 94100,475510,RD (in m.)
#
# 109: nan,nan,nan
#
# 110: 160255,416185,RD (in m.)
#
# 111: 158660,377730,RD (in m.)
#
# 112: 80226,429980,RD (in m.)
#
# 113: 130973,474388,RD (in m.)
#
# 114: 91605,450211,RD (in m.)
#
# 115: 108277,108418,446551,446631,RD (in m.),RD (in m.)
#
# 116: 114439,519730,RD (in m.)
#
# 117: 187046,578040,RD (in m.)
#
# 118: 60302,385957,RD (in m.)
#
# 119: 117305,473695,RD (in m.)
#
# 120: nan,nan,nan
#
# 121: 88312,426256,RD (in m.)
#
# 122: 51258,406253,RD (in m.)
#
# 123: 122025,529720,RD (in m.)
#
# 124: 157021,576072,RD (in m.)
#
# 125: 140838,427975,RD (in m.)
#
# 126: 161296,471543,RD (in m.)
#
# 127: 100356,460513,RD (in m.)
#
# 128: 183922,574030,RD (in m.)
#
# 129: 171580,460105,RD (in m.)
#
# 130: nan,nan,nan
#
# 131: 241582,550020,RD (in m.)
#
# 132: 182135,474160,RD (in m.)
#
# 133: 88571,88819,451306,450793,RD (in m.),RD (in m.)
#
# 134: 89500,391900,RD (in m.)
#
# 135: 88438,457745,RD (in m.)
#
# 136: 237017,551298,RD (in m.)
#
# 137: 45838,47171,397758,398235,RD (in m.),RD (in m.)
#
# 138: 151373,132143,565344,550000,RD (in m.),RD (in m.)
#
# 139: 122816,112463,407356,407373,RD (in m.),RD (in m.)
#
# 140: 193700,166000,170000,187300,457000,458000,445000,462400,RD (in m.),RD (in m.),RD (in m.),RD (in m.)
#
# 141: 99266,399614,RD (in m.)
#
# 142: 169748,433798,RD (in m.)
#
# 143: nan,nan,nan
#
# 144: 159445,415636,RD (in m.)
#
# 145: 132260,479190,RD (in m.)
#
# 146: 124876,435503,RD (in m.)
#
# 147: 179021,574405,RD (in m.)
#
# 148: nan,nan,nan
#
# 149: 167470,440910,RD (in m.)
#
# 150: 166324,369667,RD (in m.)
#
# 151: 133390,422754,RD (in m.)
#
# 152: 177048,540211,RD (in m.)
#
# 153: 90035,473910,RD (in m.)
#
# 154: 24027,378464,RD (in m.)
#
# 155: 135374,136065,463942,464602,RD (in m.),RD (in m.)
#
# 156: 184482,619441,RD (in m.)
#
# 157: 168284,364550,RD (in m.)
#
# 158: 197787,197775,197785,197798,429727,429735,429749,429739,RD (in m.),RD (in m.),RD (in m.),RD (in m.)
#
# 159: 219410,578418,RD (in m.)
#
# 160: 92692,437503,RD (in m.)
#
# 161: 171390,606075,RD (in m.)
#
# 162: 197950,581690,RD (in m.)
#
# 163: 77590,450420,RD (in m.)
#
# 164: 89667,466260,RD (in m.)
#
# 165: 109154,108944,520821,502659,RD (in m.),RD (in m.)
#
# 166: 102595,399572,RD (in m.)
#
# 167: 161602,384940,RD (in m.)
#
# 168: 141402,487976,RD (in m.)
#
# 169: 45053,395002,RD (in m.)
#
# 170: 143625,420776,RD (in m.)
#
# 171: 112223,515675,RD (in m.)
#
# 172: 202284,455072,RD (in m.)
#
# 173: 72278,434730,RD (in m.)
#
# 174: 208051,377957,RD (in m.)
#
# 175: 91146,468574,RD (in m.)
#
# 176: 156166,460209,RD (in m.)
#
# 177: nan,nan,nan
#
# 178: 203726,391736,RD (in m.)
#
# 179: 141908,439523,RD (in m.)
#
# 180: 204487,450981,RD (in m.)
#
# 181: 98403,470364,RD (in m.)
#
# 182: 203383,489194,RD (in m.)
#
# 183: 235711,235744,480067,480134,RD (in m.),RD (in m.)
#
# 184: 218099,444290,RD (in m.)
#
# 185: 195685,379945,RD (in m.)
#
# 186: 113439,527874,RD (in m.)
#
# 187: 134686,454650,RD (in m.)
#
# 188: 188830,404390,RD (in m.)
#
# 189: 106085,422832,RD (in m.)
#
# 190: 192692,323209,RD (in m.)
#
# 191: 161601,384950,RD (in m.)
#
# 192: 166593,451348,RD (in m.)
#
# 193: 202518,558937,RD (in m.)
#
# 194: 116166,489379,RD (in m.)
#
# 195: 94857,430038,RD (in m.)
#
# 196: 225402,590886,RD (in m.)
#
# 197: 181558,430596,RD (in m.)
#
# 198: 178271,420901,RD (in m.)
#
# 199: 104930,515110,RD (in m.)
#
# 200: 121600,485230,RD (in m.)
#
# 201: 125470,514420,RD (in m.)
#
# 202: 81535,447194,RD (in m.)
#
# 203: 239500,440000,RD (in m.)
#
# 204: 208814,376386,RD (in m.)
#
# 205: 26800,377130,RD (in m.)
#
# 206: 160643,459718,RD (in m.)
#
# 207: 197971,540614,RD (in m.)
#
# 208: 123720,490524,RD (in m.)
#
# 209: 84267,455402,RD (in m.)
#
# 210: 270769,561239,RD (in m.)
#
# 211: 87570,437892,RD (in m.)
#
# 212: 620162,601827,5952920,5947071,longitude/latitude (degrees),longitude/latitude (degrees)
#
# 213: 45106,397663,RD (in m.)
#
# 214: 58157,442647,RD (in m.)
#
# 215: 94476,445001,RD (in m.)
#
# 216: 125250,502500,RD (in m.)
#
# 217: 122373,487683,RD (in m.)
#
# 218: 163488,389312,RD (in m.)
#
# 219: 90568,467002,RD (in m.)
#
# 220: 149388,411068,RD (in m.)
#
# 221: 31417,392365,RD (in m.)
#
# 222: 94052,444516,RD (in m.)
#
# 223: 73538,445828,RD (in m.)
#
# 224: 261685,582667,RD (in m.)
#
# 225: 215994,488843,RD (in m.)
#
# 226: 113622,437691,RD (in m.)
#
# 227: 129540,454842,RD (in m.)
#
# 228: 100091,396624,RD (in m.)
#
# 229: 91039,442963,RD (in m.)
#
# 230: 233963,571015,RD (in m.)
#
# 231: 207506,474213,RD (in m.)
#
# 232: 185203,321577,RD (in m.)
#
# 233: 245504,594744,RD (in m.)
#
# 234: 165396,163011,425572,426747,RD (in m.),RD (in m.)
#
# 235: 153951,415037,RD (in m.)
#
# 236: 244679,583983,RD (in m.)
#
# 237: 173875,364742,RD (in m.)
#
# 238: 159790,377818,RD (in m.)
#
# 239: 132199,431810,RD (in m.)
#
# 240: 144497,474696,RD (in m.)
#
# 241: 199450,380535,RD (in m.)
#
# 242: 194190,398475,RD (in m.)
#
# 243: 152314,442919,RD (in m.)
#
# 244: 130966,534308,RD (in m.)
#
# 245: 118101,440216,RD (in m.)
#
# 246: 92740,463428,RD (in m.)
#
# 247: 159067,397759,RD (in m.)
#
# 248: nan,nan,nan
#
# 249: 208333,375440,RD (in m.)
#
# 250: 252569,564042,RD (in m.)
#
# 251: 208793,587340,RD (in m.)
#
# 252: 170810,406968,RD (in m.)
#
# 253: 105715,429360,RD (in m.)
#
# 254: 149987,399559,RD (in m.)
#
# 255: 186194,541487,RD (in m.)
#
# 256: 136700,530400,RD (in m.)
#
# 257: 151674,411772,RD (in m.)
#
# 258: 94650,547034,RD (in m.)
#
# 259: nan,nan,nan
#
# 260: 236534,472220,RD (in m.)
#
# 261: 75878,426590,RD (in m.)
#
# 262: 143647,401180,RD (in m.)
#
# 263: 113300,505600,RD (in m.)
#
# 264: 180340,390914,RD (in m.)
#
# 265: 114610,471050,RD (in m.)
#
# 266: 30168,30301,32241,395729,395413,395641,RD (in m.),RD (in m.),RD (in m.)
#
# 267: 199670,488750,RD (in m.)
#
# 268: 222500,437300,RD (in m.)
#
# 269: 98136,433590,RD (in m.)
#
# 270: 82085,445854,RD (in m.)
#
# 271: 185818,431085,RD (in m.)
#
# 272: 121081,486332,RD (in m.)
#
# 273: 89760,460668,RD (in m.)
#
# 274: 188415,494676,RD (in m.)
#
# 275: 117093,487400,RD (in m.)
#
# 276: 206381,447729,RD (in m.)
#
# 277: 198725,576699,RD (in m.)
#
# 278: 191212,503265,RD (in m.)
#
# 279: 198609,309896,RD (in m.)
#
# 280: 119067,534372,RD (in m.)
#
# 281: 196720,593292,RD (in m.)
#
# 282: 185649,317188,RD (in m.)
#
# 283: 31406,385675,RD (in m.)
#
# 284: 180224,460125,RD (in m.)
#
# 285: 195937,584136,RD (in m.)
#
# 286: 70944,446571,RD (in m.)
#
# 287: 201880,557115,RD (in m.)
#
# 288: 208218,475114,RD (in m.)
#
# 289: 146454,387134,RD (in m.)
#
# 290: 164814,443044,RD (in m.)
#
# 291: 98012,461493,RD (in m.)
#
# 292: 89105,430721,RD (in m.)
#
# 293: 121508,487903,RD (in m.)
#
# 294: 206130,586045,RD (in m.)
#
# 295: 234112,581070,RD (in m.)
#
# 296: 121162,422985,RD (in m.)
#
# 297: 105950,460621,RD (in m.)
#
# 298: 121530,124740,128920,125660,129570,515710,518120,517330,515010,515090,RD (in m.),RD (in m.),RD (in m.),RD (in m.),RD (in m.)
#
# 299: 230308,579993,RD (in m.)
#
# 300: 105000,503913,RD (in m.)
#
# 301: 144972,478935,RD (in m.)
#
# 302: 97178,474146,RD (in m.)
#
# 303: 131800,394200,RD (in m.)
#
# 304: 222980,584480,RD (in m.)
#
# 305: 247799,456637,RD (in m.)
#
# 306: nan,nan,nan
#
# 307: 202428,323255,RD (in m.)
#
# 308: 166855,505604,RD (in m.)
#
# 309: 102291,394505,RD (in m.)
#
# 310: 104910,105280,105240,491590,491660,491090,RD (in m.),RD (in m.),RD (in m.)
#
# 311: 161614,416753,RD (in m.)
#
# 312: 51992,391005,RD (in m.)
#
# 313: 181853,470200,RD (in m.)
#
# 314: 111559,539405,RD (in m.)
#
# 315: nan,nan,nan
#
# 316: 177584,476717,RD (in m.)
#
# 317: nan,nan,nan
#
# 318: 71458,448610,RD (in m.)
#
# 319: nan,nan,nan
#
# 320: nan,nan,nan
#
# 321: 150598,402690,RD (in m.)
#
# 322: 70600,447520,RD (in m.)
#
# 323: 134400,449700,RD (in m.)
#
# 324: 153666,409209,RD (in m.)
#
# 325: 141052,457029,RD (in m.)
#
# 326: 168369,432333,RD (in m.)
#
# 327: nan,nan,nan
#
# 328: 126716,424204,RD (in m.)
#
# 329: 84360,84398,84366,84366,422348,422338,422373,422382,RD (in m.),RD (in m.),RD (in m.),RD (in m.)
#
# 330: nan,nan,nan
#
# 331: 107905,107825,509750,509750,RD (in m.),RD (in m.)
#
# 332: 129290,407400,RD (in m.)
#
# 333: 101263,442703,RD (in m.)
#
# 334: 169197,369178,RD (in m.)
#
# 335: 202440,504410,RD (in m.)
#
# 336: 204175,595015,RD (in m.)
#
# 337: 118404,502124,RD (in m.)
#
# 338: 189590,414500,RD (in m.)
#
# 339: 233976,233944,582022,581954,RD (in m.),RD (in m.)
#
# 340: 79000,79200,79725,79755,458815,458630,459250,459525,RD (in m.),RD (in m.),RD (in m.),RD (in m.)
#
# 341: 139494,449037,RD (in m.)
#
# 342: 122165,456268,RD (in m.)
#
# 343: 84589,446792,RD (in m.)
#
# 344: 98640,460340,RD (in m.)
#
# 345: 165120,416060,RD (in m.)
#
# 346: 165350,164907,371102,367339,RD (in m.),RD (in m.)
#
# 347: 233044,582478,RD (in m.)
#
# 348: 66626,396231,RD (in m.)
#
# 349: 168946,389140,RD (in m.)
#
# 350: 122262,486117,RD (in m.)
#
# 351: 126861,502803,RD (in m.)
#
# 352: 230625,579680,RD (in m.)
#
# 353: 156671,454916,RD (in m.)
#
# 354: 190162,419810,RD (in m.)
#
# 355: 97300,435010,RD (in m.)
#
# 356: nan,nan,nan
#
# 357: 66541,436144,RD (in m.)
#
# 358: 144620,425910,RD (in m.)
#
# 359: 261057,584075,RD (in m.)
#
# 360: 81582,81620,81587,81635,455326,455342,455298,455321,RD (in m.),RD (in m.),RD (in m.),RD (in m.)
#
# 361: 156500,371150,RD (in m.)
#
# 362: 131450,497870,RD (in m.)
#
# 363: 129450,456750,RD (in m.)
#
# 364: 187394,435669,RD (in m.)
#
# 365: 119833,438607,RD (in m.)
#
# 366: 124932,469081,RD (in m.)
#
# 367: nan,nan,nan
#
# 368: nan,nan,nan
#
# 369: 173260,451250,RD (in m.)
#
# 370: 235865,479910,RD (in m.)
#
# 371: 150100,445420,RD (in m.)
#
# 372: 19584,395022,RD (in m.)
#
# 373: 233405,581365,RD (in m.)
#
# 374: 57658,393250,RD (in m.)
#
# 375: 214715,455765,RD (in m.)
#
# 376: 206968,372332,RD (in m.)
#
# 377: 152300,442850,RD (in m.)
#
# 378: 124677,411315,RD (in m.)
#
# 379: 61134,386950,RD (in m.)
#
# 380: 59774,400666,RD (in m.)
#
# 381: 94029,460385,RD (in m.)
#
# 382: 235083,235068,582461,582514,RD (in m.),RD (in m.)
#
# 383: 127074,467148,RD (in m.)
#
# 384: 135747,458736,RD (in m.)
#
# 385: 126980,430030,RD (in m.)
#
# 386: 109897,461527,RD (in m.)
#
# 387: 203461,578989,RD (in m.)
#
# 388: nan,nan,nan
#
# 389: 109551,474747,RD (in m.)
#
# 390: 237052,438683,RD (in m.)
#
# 391: 89656,473005,RD (in m.)
#
# 392: 202362,324071,RD (in m.)
#
# 393: 154970,374632,RD (in m.)
#
# 394: 147215,440439,RD (in m.)
#
# 395: 105675,506277,RD (in m.)
#
# 396: 173331,406923,RD (in m.)
#
# 397: 162948,161639,162280,534717,534433,533592,RD (in m.),RD (in m.),RD (in m.)
#
# 398: 146700,557123,RD (in m.)
#
# 399: nan,nan,nan
#
# 400: 195750,435243,RD (in m.)
#
# 401: 205895,205946,205293,205397,564075,563588,563317,563685,RD (in m.),RD (in m.),RD (in m.),RD (in m.)
#
# 402: nan,nan,nan
#
# 403: 93590,462450,RD (in m.)
#
# 404: 162718,433083,RD (in m.)
#
# 405: 105245,106695,404630,403390,RD (in m.),RD (in m.)
#
# 406: 201557,448049,RD (in m.)
#
# 407: 185420,432790,RD (in m.)
#
# 408: 61000,365911,RD (in m.)
#
# 409: 114560,411595,RD (in m.)
#
# 410: 161635,470270,RD (in m.)
#
# 411: 111380,442160,RD (in m.)
#
# 412: 84636,84581,440179,439553,RD (in m.),RD (in m.)
#
# 413: 157546,466875,RD (in m.)
#
# 414: 184820,432530,RD (in m.)
#
# 415: 189330,189170,189620,189250,325010,325060,324910,325090,RD (in m.),RD (in m.),RD (in m.),RD (in m.)
#
# 416: 149380,450260,RD (in m.)
#
# 417: nan,nan,nan
#
# 418: 116373,117357,118503,534125,529485,529118,RD (in m.),RD (in m.),RD (in m.)
#
# 419: 174600,445400,RD (in m.)
#
# 420: 191696,581374,RD (in m.)
#
# 421: 113613,437324,RD (in m.)
#
# 422: nan,nan,nan
#
# 423: 111945,467739,RD (in m.)
#
# 424: 88959,88901,88705,436929,436869,437282,RD (in m.),RD (in m.),RD (in m.)
#
# 425: 124850,462250,RD (in m.)
#
# 426: 230336,594830,RD (in m.)
#
# 427: 117006,534083,RD (in m.)
#
# 428: 91363,467871,RD (in m.)
#
# 429: 192022,350820,RD (in m.)
#
# 430: nan,nan,nan
#
# 431: nan,nan,nan
#
# 432: 247552,528952,RD (in m.)
#
# 433: 172584,173196,449798,448625,RD (in m.),RD (in m.)
#
# 434: 235778,591200,RD (in m.)
#
# 435: 176215,432036,RD (in m.)
#
# 436: 91283,446993,RD (in m.)
#
# 437: 93342,432268,RD (in m.)
#
# 438: 111909,528004,RD (in m.)
#
# 439: 223410,222456,221995,514932,514444,514870,RD (in m.),RD (in m.),RD (in m.)
#
# 440: nan,nan,nan
#
# 441: 125754,406339,RD (in m.)
#
# 442: 157300,366000,RD (in m.)
#
# 443: 96147,460999,RD (in m.)
#
# 444: 238033,237980,598267,598519,RD (in m.),RD (in m.)
#
# 445: 104626,455620,RD (in m.)
#
# 446: 71014,71044,435264,435285,RD (in m.),RD (in m.)
#
# 447: 197870,377806,RD (in m.)
#
# 448: nan,nan,nan
#
# 449: 109560,430870,RD (in m.)
#
# 450: 156455,461135,RD (in m.)
#
# 451: nan,nan,nan
#
# 452: 233424,557481,RD (in m.)
#
# 453: 235500,438040,RD (in m.)
#
# 454: 51194,392493,RD (in m.)
#
# 455: 125210,409570,RD (in m.)
#
# 456: 94231,476323,RD (in m.)
#
# 457: 89305,472500,RD (in m.)
#
# 458: 124260,405240,RD (in m.)
#
# 459: nan,nan,nan
#
# 460: 144400,474115,RD (in m.)
#
# 461: 163670,431939,RD (in m.)
#
# 462: 51724,389045,RD (in m.)
#
# 463: 194345,472260,RD (in m.)
#
# 464: 191343,443707,RD (in m.)
#
# 465: nan,nan,nan
#
# 466: 191016,443380,RD (in m.)
#
# 467: 98747,426966,RD (in m.)
#
# 468: 222280,506595,RD (in m.)
#
# 469: 32400,400175,RD (in m.)
#
# 470: 88608,88376,458342,458514,RD (in m.),RD (in m.)
#
# 471: nan,nan,nan
#
# 472: 224271,549333,RD (in m.)
#
# 473: 170858,558181,RD (in m.)
#
# 474: 139591,468600,RD (in m.)
#
# 475: 191555,444230,RD (in m.)
#
# 476: 77123,447925,RD (in m.)
#
# 477: 155841,378966,RD (in m.)
#
# 478: 115640,408166,RD (in m.)
#
# 479: 125680,451525,RD (in m.)
#
# 480: 183050,416063,RD (in m.)
#
# 481: 158401,158541,576420,576521,RD (in m.),RD (in m.)
#
# 482: 97657,421967,RD (in m.)
#
# 483: nan,nan,nan
#
# 484: 104240,458050,RD (in m.)
#
# 485: 193031,192775,192602,193006,193774,340853,341196,341864,342343,341311,RD (in m.),RD (in m.),RD (in m.),RD (in m.),RD (in m.)
#
# 486: 146400,427225,RD (in m.)
#
# 487: 156840,433135,RD (in m.)
#
# 488: 136710,462810,RD (in m.)
#
# 489: 116040,394939,RD (in m.)
#
# 490: 164675,416465,RD (in m.)
#
# 491: nan,nan,nan
#
# 492: 31070,387683,RD (in m.)
#
# 493: 139726,139602,457877,458066,RD (in m.),RD (in m.)
#
# 494: 175350,363325,RD (in m.)
#
# 495: 79540,457650,RD (in m.)
#
# 496: 132723,447237,RD (in m.)
#
# 497: 195888,559652,RD (in m.)
#
# 498: nan,nan,nan
#
# 499: 211539,464215,RD (in m.)
#
# 500: 178845,358065,RD (in m.)
#
# 501: 169012,477705,RD (in m.)
#
# 502: 84877,447064,RD (in m.)
#
# 503: 195634,432729,RD (in m.)
#
# 504: 149315,147939,141818,141812,431987,430588,431775,432491,RD (in m.),RD (in m.),RD (in m.),RD (in m.)
#
# 505: 221172,522655,RD (in m.)
#
# 506: 112753,392101,RD (in m.)
#
# 507: 189807,459492,RD (in m.)
#
# 508: 79165,458858,RD (in m.)
#
# 509: 106356,430031,RD (in m.)
#
# 510: 206563,463599,RD (in m.)
#
# 511: 186640,145007,164078,170000,178590,160097,173625,181240,181164,180190,186394,176845,159100,151052,171579,158360,519675,482740,481070,492040,495317,502252,509870,508740,507435,506780,504169,524776,492710,479637,510462,476870,RD (in m.),RD (in m.),RD (in m.),RD (in m.),RD (in m.),RD (in m.),RD (in m.),RD (in m.),RD (in m.),RD (in m.),RD (in m.),RD (in m.),RD (in m.),RD (in m.),RD (in m.),RD (in m.)
#
# 512: 148864,418744,RD (in m.)
#
# 513: 196241,355946,RD (in m.)
#
# 514: 24087,399120,RD (in m.)
#
# 515: 119543,448726,RD (in m.)
#
# 516: 110707,409124,RD (in m.)
#
# 517: 105303,425686,RD (in m.)
#
# 518: 209290,522530,RD (in m.)
#
# 519: 136775,473300,RD (in m.)
#
# 520: nan,nan,nan
#
# 521: 64183,396234,RD (in m.)
#
# 522: 233718,581876,RD (in m.)
#
# 523: 193817,400050,RD (in m.)
#
# 524: 105500,459443,RD (in m.)
#
# 525: 240073,240420,578323,578275,RD (in m.),RD (in m.)
#
# 526: 112514,112408,112500,112413,549352,549331,549425,549401,RD (in m.),RD (in m.),RD (in m.),RD (in m.)
#
# 527: 157663,408436,RD (in m.)
#
# 528: 168560,478224,RD (in m.)
#
# 529: 50048,391891,RD (in m.)
#
# 530: 151533,381677,RD (in m.)
#
# 531: 206962,384067,RD (in m.)
#
# 532: 168040,438260,RD (in m.)
#
# 533: 201215,381025,RD (in m.)
#
# 534: 169924,466831,RD (in m.)
#
# 535: 135575,433050,RD (in m.)
#
# 536: 261045,563469,RD (in m.)
#
# 537: 207581,387868,RD (in m.)
#
# 538: 25053,393697,RD (in m.)
#
# 539: 142696,391636,RD (in m.)
#
# 540: 94143,530805,RD (in m.)
#
# 541: 99861,385196,RD (in m.)
#
# 542: 128820,457809,RD (in m.)
#
# 543: nan,nan,nan
#
# 544: 152158,414373,RD (in m.)
#
# 545: 97789,97804,97736,97750,430626,430633,430748,430755,RD (in m.),RD (in m.),RD (in m.),RD (in m.)
#
# 546: 97160,461694,RD (in m.)
#
# 547: 118488,407562,RD (in m.)
#
# 548: 159250,546815,RD (in m.)
#
# 549: 230693,571539,RD (in m.)
#
# 550: 28494,392509,RD (in m.)
#
# 551: 150834,399991,RD (in m.)
#
# 552: 49987,392087,RD (in m.)
#
# 553: nan,nan,nan
#
# 554: 215601,432529,RD (in m.)
#
# 555: 153006,430707,RD (in m.)
#
# 556: 132089,399556,RD (in m.)
#
# 557: 90019,393314,RD (in m.)
#
# 558: 110413,450420,RD (in m.)
#
# 559: 234600,579100,RD (in m.)
#
# 560: 131483,447730,RD (in m.)
#
# 561: 180739,470193,RD (in m.)
#
# 562: nan,nan,nan
#
# 563: 186940,352915,RD (in m.)
#
# 564: nan,nan,nan
#
# 565: 200575,324256,RD (in m.)
#
# 566: 204246,472785,RD (in m.)
#
# 567: 123553,398929,RD (in m.)
#
# 568: 89542,420603,RD (in m.)
#
# 569: nan,nan,nan
#
# 570: nan,nan,nan
#
# 571: 56023,400916,RD (in m.)
#
# 572: 24624,393621,RD (in m.)
#
# 573: 183876,354279,RD (in m.)
#
# 574: 160874,465712,RD (in m.)
#
# 575: 254404,576549,RD (in m.)
#
# 576: 253617,520059,RD (in m.)
#
# 577: nan,nan,nan
#
# 578: 115979,437314,RD (in m.)
#
# 579: 59641,374262,RD (in m.)
#
# 580: 157212,398336,RD (in m.)
#
# 581: 232820,447170,RD (in m.)
#
# 582: 182150,478550,RD (in m.)
#
# 583: 135700,392000,RD (in m.)
#
# 584: 203028,320570,RD (in m.)
#
# 585: 201856,498638,RD (in m.)
#
# 586: 193602,392225,RD (in m.)
#
# 587: 51006,50975,391561,391562,RD (in m.),RD (in m.)
#
# 588: 165251,433127,RD (in m.)
#
# 589: 214995,432775,RD (in m.)
#
# 590: 182050,184385,437995,437930,RD (in m.),RD (in m.)
#
# 591: 160610,449834,RD (in m.)
#
# 592: 66846,400768,RD (in m.)
#
# 593: 210938,437149,RD (in m.)
#
# 594: 201447,448375,RD (in m.)
#
# 595: 157424,168304,194507,169120,142348,138036,136079,160533,429316,433984,431192,435565,425331,425484,425209,433882,RD (in m.),RD (in m.),RD (in m.),RD (in m.),RD (in m.),RD (in m.),RD (in m.),RD (in m.)
#
# 596: 146895,413668,RD (in m.)
#
# 597: 105660,460500,RD (in m.)
#
# 598: 120968,458656,RD (in m.)
#
# 599: 130365,422475,RD (in m.)
#
# 600: 82100,435900,RD (in m.)
#
# 601: 82035,434622,RD (in m.)
#
# 602: 71075,430801,RD (in m.)
#
# 603: 188132,594325,RD (in m.)
#
# 604: 159645,375160,RD (in m.)
#
# 605: 197931,566041,RD (in m.)
#
# 606: 194280,467630,RD (in m.)
#
# 607: 183390,443600,RD (in m.)
#
# 608: 62633,62742,62663,367192,367177,367201,RD (in m.),RD (in m.),RD (in m.)
#
# 609: 87191,464329,RD (in m.)
#
# 610: nan,nan,nan
#
# 611: 116260,516690,RD (in m.)
#
# 612: 28025,400123,RD (in m.)
#
# 613: nan,nan,nan
#
# 614: 152147,385472,RD (in m.)
#
# 615: 192904,421842,RD (in m.)
#
# 616: nan,nan,nan
#
# 617: 22750,391875,RD (in m.)
#
# 618: 234025,581676,RD (in m.)
#
# 619: 37951,402851,RD (in m.)
#
# 620: 186336,490687,RD (in m.)
#
# 621: 84497,401011,RD (in m.)
#
# 622: 211074,516345,RD (in m.)
#
# 623: 20851,393889,RD (in m.)
#
# 624: nan,nan,nan
#
# 625: 198540,357876,RD (in m.)
#
# 626: 135359,437225,RD (in m.)
#
# 627: 17076,411679,RD (in m.)
#
# 628: 167760,174601,436785,437828,RD (in m.),RD (in m.)
#
# 629: 239696,533652,RD (in m.)
#
# 630: nan,nan,nan
#
# 631: 131525,447998,RD (in m.)
#
# 632: 160150,397370,RD (in m.)
#
# 633: 179567,390084,RD (in m.)
#
# 634: 129230,429870,RD (in m.)
#
# 635: 101685,502180,RD (in m.)
#
# 636: 166450,460563,RD (in m.)
#
# 637: 100655,429395,RD (in m.)
#
# 638: 141679,399452,RD (in m.)
#
# 639: 120872,425100,RD (in m.)
#
# 640: 70561,435628,RD (in m.)
#
# 641: 152226,413277,RD (in m.)
#
# 642: 156750,454900,RD (in m.)
#
# 643: 117900,447730,RD (in m.)
#
# 644: 155340,410145,RD (in m.)
#
# 645: 220361,518608,RD (in m.)
#
# 646: 88355,469792,RD (in m.)
#
# 647: 178395,489932,RD (in m.)
#
# 648: 85909,438667,RD (in m.)
#
# 649: 87462,426812,RD (in m.)
#
# 650: 64676,396115,RD (in m.)
#
# 651: 93657,423654,RD (in m.)
#
# 652: 193140,471831,RD (in m.)
#
# 653: 172192,438600,RD (in m.)
#
# 654: nan,nan,nan
#
# 655: 76255,431101,RD (in m.)
#
# 656: 194952,481657,RD (in m.)
#
# 657: 121259,441926,RD (in m.)
#
# 658: 245135,589260,RD (in m.)
#
# 659: 113747,397630,RD (in m.)
#
# 660: 250123,599971,RD (in m.)
#
# 661: 168470,453237,RD (in m.)
#
# 662: 137240,398090,RD (in m.)
#
# 663: 141079,458551,RD (in m.)
#
# 664: 100000,395160,RD (in m.)
#
# 665: 165475,402500,RD (in m.)
#
# 666: nan,nan,nan
#
# 667: 156455,571210,RD (in m.)
#
# 668: 151134,463794,RD (in m.)
#
# 669: 72055,429697,RD (in m.)
#
# 670: nan,nan,nan
#
# 671: 104723,490577,RD (in m.)
#
# 672: 229508,455140,RD (in m.)
#
# 673: 105035,459958,RD (in m.)
#
# 674: 41643,366878,RD (in m.)
#
# 675: 240965,592916,RD (in m.)
#
# 676: 223330,432855,RD (in m.)
#
# 677: 94089,390410,RD (in m.)
#
# 678: nan,nan,nan
#
# 679: 172513,459344,RD (in m.)
#
# 680: 85829,446912,RD (in m.)
#
# 681: 92195,456746,RD (in m.)
#
# 682: 102184,489926,RD (in m.)
#
# 683: 255888,557244,RD (in m.)
#
# 684: 80997,400208,RD (in m.)
#
# 685: 82779,446621,RD (in m.)
#
# 686: 62136,388780,RD (in m.)
#
# 687: 115640,408157,RD (in m.)
#
# 688: nan,nan,nan
#
# 689: 250000,534924,RD (in m.)
#
# 690: 87300,456575,RD (in m.)
#
# 691: 86330,458940,RD (in m.)
#
# 692: 103947,488177,RD (in m.)
#
# 693: 169400,442800,RD (in m.)
#
# 694: 91024,462800,RD (in m.)
#
# 695: nan,nan,nan
#
# 696: 124519,432152,RD (in m.)
#
# 697: 186774,427619,RD (in m.)
#
# 698: nan,nan,nan
#
# 699: 183689,437822,RD (in m.)
#
# 700: 79730,451135,RD (in m.)
#
# 701: 157984,429163,RD (in m.)
#
# 702: 168098,374507,RD (in m.)
#
# 703: 188477,470202,RD (in m.)
#
# 704: 196850,497786,RD (in m.)
#
# 705: 235875,591201,RD (in m.)
#
# 706: 214048,458761,RD (in m.)
#
# 707: 212499,212782,440124,440139,RD (in m.),RD (in m.)
#
# 708: 245045,442637,RD (in m.)
#
# 709: 177355,184055,397546,386915,RD (in m.),RD (in m.)
#
# 710: 100071,464879,RD (in m.)
#
# 711: 93570,439053,RD (in m.)
#
# 712: 182329,368744,RD (in m.)
#
# 713: 99179,385192,RD (in m.)
#
# 714: 233660,448850,RD (in m.)
#
# 715: 197306,402161,RD (in m.)
#
# 716: nan,nan,nan
#
# 717: 170268,474349,RD (in m.)
#
# 718: 201477,351587,RD (in m.)
#
# 719: 193250,599700,RD (in m.)
#
# 720: 79492,79594,79625,79505,79468,456785,456798,456747,456669,456727,RD (in m.),RD (in m.),RD (in m.),RD (in m.),RD (in m.)
#
# 721: 203311,369013,RD (in m.)
#
# 722: 194220,463240,RD (in m.)
#
# 723: 208250,375375,RD (in m.)
#
# 724: 195705,195755,593222,593192,RD (in m.),RD (in m.)
#
# 725: nan,nan,nan
#
# 726: 155300,379660,RD (in m.)
#
# 727: 180600,439800,RD (in m.)
#
# 728: 206492,435199,RD (in m.)
#
# 729: 208800,373800,RD (in m.)
#
# 730: 264423,588853,RD (in m.)
#
# 731: 199873,593974,RD (in m.)
#
# 732: 125025,502600,RD (in m.)
#
# 733: 113000,449321,RD (in m.)
#
# 734: 109220,425770,RD (in m.)
#
# 735: 126500,423947,RD (in m.)
#
# 736: 65798,438354,RD (in m.)
#
# 737: 154202,432392,RD (in m.)
#
# 738: 121710,486971,RD (in m.)
#
# 739: 74267,449377,RD (in m.)
#
# 740: 189085,348680,RD (in m.)
#
# 741: 88966,448327,RD (in m.)
#
# 742: 158651,433922,RD (in m.)
#
# 743: 237900,556500,RD (in m.)
#
# 744: 192910,412390,RD (in m.)
#
# 745: 117800,514100,RD (in m.)
#
# 746: 124517,404126,RD (in m.)
#
# 747: 110124,541016,RD (in m.)
#
# 748: 109270,450540,RD (in m.)
#
# 749: 266225,564456,RD (in m.)
#
# 750: 196480,363450,RD (in m.)
#
# 751: 129683,391889,RD (in m.)
#
# 752: 226707,527528,RD (in m.)
#
# 753: 142456,500377,RD (in m.)
#
# 754: 136983,480775,RD (in m.)
#
# 755: 200022,571305,RD (in m.)
#
# 756: 217501,589341,RD (in m.)
#
# 757: 138581,448688,RD (in m.)
#
# 758: 65956,428647,RD (in m.)
#
# 759: 202905,562350,RD (in m.)
#
# 760: 152197,414556,RD (in m.)
#
# 761: 269136,543641,RD (in m.)
#
# 762: 209923,448297,RD (in m.)
#
# 763: 181477,329663,RD (in m.)
#
# 764: 145765,145715,475050,475085,RD (in m.),RD (in m.)
#
# 765: 109935,447884,RD (in m.)
#
# 766: 110402,520438,RD (in m.)
#
# 767: 79082,455360,RD (in m.)
#
# 768: 120682,486333,RD (in m.)
#
# 769: 160550,398144,RD (in m.)
#
# 770: 123165,452402,RD (in m.)
#
# 771: 102985,398414,RD (in m.)
#
# 772: 234988,583423,RD (in m.)
#
# 773: nan,nan,nan
#
# 774: 86747,461690,RD (in m.)
#
# 775: 136760,480781,RD (in m.)
#
# 776: 126400,502400,RD (in m.)
#
# 777: 33543,390216,RD (in m.)
#
# 778: 232978,552949,RD (in m.)
#
# 779: 197039,503774,RD (in m.)
#
# 780: 86557,424453,RD (in m.)
#
# 781: 188209,428990,RD (in m.)
#
# 782: 201037,398106,RD (in m.)
#
# 783: 182979,518837,RD (in m.)
#
# 784: 75000,74615,450250,450120,RD (in m.),RD (in m.)
#
# 785: nan,nan,nan
#
# 786: nan,nan,nan
#
# 787: 235735,533727,RD (in m.)
#
# 788: 191455,433338,RD (in m.)
#
# 789: 104130,429340,RD (in m.)
#
# 790: 192435,393718,RD (in m.)
#
# 791: 90904,472152,RD (in m.)
#
# 792: 142586,523388,RD (in m.)
#
# 793: nan,nan,nan
#
# 794: nan,nan,nan
#
# 795: 97197,474652,RD (in m.)
#
# 796: 51815,406502,RD (in m.)
#
# 797: 193391,321709,RD (in m.)
#
# 798: 93540,462010,RD (in m.)
#
# 799: 241010,562027,RD (in m.)
#
# 800: 132447,536590,RD (in m.)
#
# 801: 204924,583409,RD (in m.)
#
# 802: 178617,356701,RD (in m.)
#
# 803: 244230,558282,RD (in m.)
#
# 804: 193896,371985,RD (in m.)
#
# 805: 233137,500766,RD (in m.)
#
# 806: 195630,592178,RD (in m.)
#
# 807: 208866,390616,RD (in m.)
#
# 808: 199076,441088,RD (in m.)
#
# 809: 75738,433876,RD (in m.)
#
# 810: 162850,505980,RD (in m.)
#
# 811: 165739,453868,RD (in m.)
#
# 812: 197009,323566,RD (in m.)
#
# 813: 191788,468173,RD (in m.)
#
# 814: 150072,151200,149792,482650,483141,484626,RD (in m.),RD (in m.),RD (in m.)
#
# 815: 179786,591224,RD (in m.)
#
# 816: nan,nan,nan
#
# 817: 104331,487861,RD (in m.)
#
# 818: 249104,476303,RD (in m.)
#
# 819: 131380,461435,RD (in m.)
#
# 820: 138933,392917,RD (in m.)
#
# 821: 231960,584270,RD (in m.)
#
# 822: 94580,396660,RD (in m.)
#
# 823: 160618,402985,RD (in m.)
#
# 824: 118109,565162,RD (in m.)
#
# 825: nan,nan,nan
#
# 826: 80433,430278,RD (in m.)
#
# 827: nan,nan,nan
#
# 828: nan,nan,nan
#
# 829: 131877,415940,RD (in m.)
#
# 830: 123250,432960,RD (in m.)
#
# 831: 90030,445535,RD (in m.)
#
# 832: 80612,399979,RD (in m.)
#
# 833: 188091,418124,RD (in m.)
#
# 834: 199356,379701,RD (in m.)
#
# 835: 178149,392115,RD (in m.)
#
# 836: 88012,461579,RD (in m.)
#
# 837: 91810,396010,RD (in m.)
#
# 838: 175696,355576,RD (in m.)
#
# 839: nan,nan,nan
#
# 840: 78620,78650,78750,78750,450415,450335,450275,450305,RD (in m.),RD (in m.),RD (in m.),RD (in m.)
#
# 841: 166595,571033,RD (in m.)
#
# 842: 90820,472180,RD (in m.)
#
# 843: 200621,538289,RD (in m.)
#
# 844: 200663,398530,RD (in m.)
#
# 845: 80319,455729,RD (in m.)
#
# 846: 49079,391569,RD (in m.)
#
# 847: 202016,201895,320094,320480,RD (in m.),RD (in m.)
#
# 848: 19500,363900,RD (in m.)
#
# 849: 181743,570256,RD (in m.)
#
# 850: 102950,487947,RD (in m.)
#
# 851: 107784,422409,RD (in m.)
#
# 852: 225700,431820,RD (in m.)
#
# 853: 233328,581785,RD (in m.)
#
# 854: 103555,499770,RD (in m.)
#
# 855: 165396,163011,425572,426747,RD (in m.),RD (in m.)
#
# 856: 128446,398145,RD (in m.)
#
# 857: 133330,482670,RD (in m.)
#
# 858: 231249,231500,231457,231225,584968,585078,585125,585020,RD (in m.),RD (in m.),RD (in m.),RD (in m.)
#
# 859: 166392,378601,RD (in m.)
#
# 860: 205638,206195,207233,353489,353560,353686,RD (in m.),RD (in m.),RD (in m.)
#
# 861: 79841,440509,RD (in m.)
#
# 862: 104909,487014,RD (in m.)
#
# 863: 152565,376834,RD (in m.)
#
# 864: 205401,585473,RD (in m.)
#
# 865: 178277,425692,RD (in m.)
#
# 866: 177067,363146,RD (in m.)
#
# 867: 105008,425349,RD (in m.)
#
# 868: 94084,463774,RD (in m.)
#
# 869: 188156,436424,RD (in m.)
#
# 870: 245459,594763,RD (in m.)
#
# 871: 81464,455391,RD (in m.)
#
# 872: 174003,441813,RD (in m.)
#
# 873: 23194,475450,RD (in m.)
#
# 874: 174100,481699,RD (in m.)
#
# 875: 192911,192923,192916,192926,421168,421169,421127,421126,RD (in m.),RD (in m.),RD (in m.),RD (in m.)
#
# 876: 123332,483803,RD (in m.)
#
# 877: 179195,177350,452820,452870,RD (in m.),RD (in m.)
#
# 878: 130946,390486,RD (in m.)
#
# 879: 102170,426855,RD (in m.)
#
# 880: 198026,550726,RD (in m.)
#
# 881: 226538,587753,RD (in m.)
#
# 882: 144807,454859,RD (in m.)
#
# 883: 113133,514030,RD (in m.)
#
# 884: 100510,460760,RD (in m.)
#
# 885: 186244,186282,186184,186266,352234,352268,352276,352291,RD (in m.),RD (in m.),RD (in m.),RD (in m.)
#
# 886: 220425,436831,RD (in m.)
#
# 887: nan,nan,nan
#
# 888: 195895,537393,RD (in m.)
#
# 889: 191678,192054,466783,466887,RD (in m.),RD (in m.)
#
# 890: 177220,434300,RD (in m.)
#
# 891: 121627,515146,RD (in m.)
#
# 892: 149885,471416,RD (in m.)
#
# 893: nan,nan,nan
#
# 894: 78271,439370,RD (in m.)
#
# 895: 121816,491137,RD (in m.)
#
# 896: 87425,469770,RD (in m.)
#
# 897: 149420,465942,RD (in m.)
#
# 898: 79495,451000,RD (in m.)
#
# 899: 148838,407184,RD (in m.)
#
# 900: 195866,541077,RD (in m.)
#
# 901: 197449,355785,RD (in m.)
#
# 902: 220178,474911,RD (in m.)
#
# 903: 111680,509960,RD (in m.)
#
# 904: 95072,468376,RD (in m.)
#
# 905: 201222,398126,RD (in m.)
#
# 906: 161261,422073,RD (in m.)
#
# 907: 221739,599073,RD (in m.)
#
# 908: 153503,153645,153132,153025,410428,410810,411947,412248,RD (in m.),RD (in m.),RD (in m.),RD (in m.)
#
# 909: 105550,450308,RD (in m.)
#
# 910: 199882,502578,RD (in m.)
#
# 911: 108213,463326,RD (in m.)
#
# 912: 90928,471573,RD (in m.)
#
# 913: nan,nan,nan
#
# 914: 170276,401233,RD (in m.)
#
# 915: 152058,384891,RD (in m.)
#
# 916: 139400,448900,RD (in m.)
#
# 917: 239252,580884,RD (in m.)
#
# 918: 106822,504926,RD (in m.)
#
# 919: 121280,567332,RD (in m.)
#
# 920: 184517,183882,484897,484460,RD (in m.),RD (in m.)
#
# 921: 98908,477600,RD (in m.)
#
# 922: 263640,579125,RD (in m.)
#
# 923: 178749,423624,RD (in m.)
#
# 924: 129800,398000,RD (in m.)
#
# 925: 198092,474803,RD (in m.)
#
# 926: 100668,394119,RD (in m.)
#
# 927: 104152,488548,RD (in m.)
#
# 928: 250756,250808,250773,250815,474570,474572,474670,474661,RD (in m.),RD (in m.),RD (in m.),RD (in m.)
#
# 929: 136928,430174,RD (in m.)
#
# 930: nan,nan,nan
#
# 931: nan,nan,nan
#
# 932: 43678,416810,RD (in m.)
#
# 933: 88831,430780,RD (in m.)
#
# 934: nan,nan,nan
#
# 935: 115005,437655,RD (in m.)
#
# 936: 197351,542335,RD (in m.)
#
# 937: 142720,143315,142735,142545,469975,469820,469090,469175,RD (in m.),RD (in m.),RD (in m.),RD (in m.)
#
# 938: 136174,437207,RD (in m.)
#
# 939: 126930,476040,RD (in m.)
#
# 940: 136397,436879,RD (in m.)
#
# 941: 120145,495085,RD (in m.)
#
# 942: 162975,460670,RD (in m.)
#
# 943: 31280,389610,RD (in m.)
#
# 944: 105360,105142,105055,452193,450945,450289,RD (in m.),RD (in m.),RD (in m.)
#
# 945: nan,nan,nan
#
# 946: 124200,443055,RD (in m.)
#
# 947: 155350,457400,RD (in m.)
#
# 948: 223590,442430,RD (in m.)
#
# 949: 193063,438550,RD (in m.)
#
# 950: 158455,404015,RD (in m.)
#
# 951: 140622,472069,RD (in m.)
#
# 952: 24096,393605,RD (in m.)
#
# 953: 241821,568132,RD (in m.)
#
# 954: 113668,399235,RD (in m.)
#
# 955: 25042,381076,RD (in m.)
#
# 956: 97470,390001,RD (in m.)
#
# 957: 96390,448030,RD (in m.)
#
# 958: 189039,418912,RD (in m.)
#
# 959: 54883,425438,RD (in m.)
#
# 960: 123876,472840,RD (in m.)
#
# 961: 243709,586595,RD (in m.)
#
# 962: 220750,446000,RD (in m.)
#
# 963: 114440,520005,RD (in m.)
#
# 964: 185155,380897,RD (in m.)
#
# 965: 207100,372784,RD (in m.)
#
# 966: 201675,458025,RD (in m.)
#
# 967: 155850,409830,RD (in m.)
#
# 968: 80966,454903,RD (in m.)
#
# 969: 233517,546031,RD (in m.)
#
# 970: 202504,325969,RD (in m.)
#
# 971: 122888,494215,RD (in m.)
#
# 972: 183208,183259,183266,183203,385874,385880,385850,385818,RD (in m.),RD (in m.),RD (in m.),RD (in m.)
#
# 973: 101085,428410,RD (in m.)
#
# 974: 81152,429685,RD (in m.)
#
# 975: nan,nan,nan
#
# 976: 119888,412020,RD (in m.)
#
# 977: 98820,426920,RD (in m.)
#
# 978: 87139,437200,RD (in m.)
#
# 979: 106932,424303,RD (in m.)
#
# 980: nan,nan,nan
#
# 981: 97140,454580,RD (in m.)
#
# 982: 234030,580816,RD (in m.)
#
# 983: 191922,471101,RD (in m.)
#
# 984: 110700,460840,RD (in m.)
#
# 985: 230990,536780,RD (in m.)
#
# 986: 182567,410827,RD (in m.)
#
# 987: 166487,577572,RD (in m.)
#
# 988: 239950,468875,RD (in m.)
#
# 989: 79080,79100,79040,79025,457555,457530,457490,457520,RD (in m.),RD (in m.),RD (in m.),RD (in m.)
#
# 990: 244852,588218,RD (in m.)
#
# 991: 125289,474021,RD (in m.)
#
# 992: 179150,516367,RD (in m.)
#
# 993: 106333,500115,RD (in m.)
#
# 994: 194726,478003,RD (in m.)
#
# 995: 190488,444113,RD (in m.)
#
# 996: 109655,438940,RD (in m.)
#
# 997: 63151,382615,RD (in m.)
#
# 998: 119913,118263,406684,404638,RD (in m.),RD (in m.)
#
# 999: 217305,556644,RD (in m.)
