# %% [markdown]
# # Conversion of Rijksdriehoek to WGS84 coordinates
# Or the other way around

# %%
import pandas as pd
from scripts.convert_rd_to_wgs84 import convert_multiple_pairs
    
# Load the data
df = pd.read_csv('../data/eval_spatialCoverageText.csv')


# Apply the function to the DataFrame
df['dansWGS84'] = df.apply(convert_multiple_pairs, axis=1)

# Save the updated DataFrame
df.to_csv('../data/conversion_rd_to_wgs84.csv', index=False)
# Out:
# /usr/lib/python3/dist-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# /usr/lib/python3/dist-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# ...

# %%
df
# Out:
#                          id  \
# 0    10.17026/dans-z2t-fr88
# 1    10.17026/dans-xx7-w66k
# 2    10.17026/dans-xdh-uzt5
# 3    10.17026/dans-zeu-pe5h
# 4    10.17026/dans-z3c-p6t9
# ..                      ...
# 213      10.17026/AR/3NN2CO
# 214  10.17026/dans-zxj-k3yb
# 215  10.17026/dans-zkw-qwn8
# 216  10.17026/dans-zt5-ayk6
# 217  10.17026/dans-xqj-rwu2
#
#                                                  title  \
# 0                                 Beerseweg 6 Oirschot
# 1                                NABO - locatie Beesel
# 2    Bloemendaal, Brederodelaan 34 Gemeente Bloemen...
# 3    Locatie 'Dr. van Noortstraat 6' te Lienden, ge...
# 4                         bbbley 1, 2, 3 en 4 (Leyweg)
# ..                                                 ...
# 213    Janninkcomplex Haaksbergerstraat 147, Enschede.
# 214  Archeologisch bureauonderzoek Ugchelseweg 78 t...
# 215         Westdorpe Molenstraat. Gemeente Terneuzen.
# 216             Gameren 't Slot' (gemeente Zaltbommel)
# ...

# %%
# Inspect dansWGS84 column
wg = df['dansWGS84'].to_list()
wg
# Out:
# ['51.49531200843751,5.295774561853206',
#  '51.26679573469417,6.066293478115079',
#  '52.42063855875875,4.622642112922777',
#  '51.946998302139036,5.51810583059402',
#  '52.050731945922436,4.278028147476343',
#  '51.88361048819214,5.880711199296572',
#  '47.97909203401914,3.3161106595587975',
#  '52.2160945818556,4.645997048007205',
#  '53.046950384739404,4.9327773235787316',
#  '51.87041720847043,6.341187035408111',
#  '53.316123200908265,6.86493981418489',
#  '51.8630400098398,5.782272423897524',
#  '51.33029345299336,5.458438982817318;51.33010525781396,5.457506063960182',
#  '51.568544340807335,4.542108629780993',
#  '52.804641357455175,6.606462146816975',
#  '53.225405778189156,6.562161000410384',
#  '51.65193964955557,5.0383073735241',
#  '52.197044613076685,5.006479710592357',
#  'None',
#  '52.077818921137926,4.249200708566625',
#  '51.934456900393805,5.5734403904360414',
#  '51.770915199951915,4.659171696423778',
#  '52.74182153314953,6.689290440452605',
#  '154168, 391902',
# ...
