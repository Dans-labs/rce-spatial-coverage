# %% [markdown]
# # Explore PAN datasets
# Find out whether:
# - all PAN datasets have consistent entries for municipalities (`dansTemporalSpatial:dansSpatialCoverageText`).
#   - answer: YES.
#     all PAN datasets have an entry for SpatialCoverageText, and they are always a tuple of the structure (Municipality, NDL).
#     in some cases, a number is given instead of a municipality name. these can be filtered out or converted.

# %%
import sys
# Specify the path to the scripts folder
sys.path.append('../scripts/')
from mongodb import load_data

# %%
collection = load_data()

# %%
type(collection)
# Out:
# pymongo.collection.Collection

# %% [markdown]
# ### Find out how many times each municipality occurs in the PAN datasets

# %%
# Step 1: Filter datasets with a certain value for a field
filter_field = "ore:describes.author.citation:authorName"
filter_value = "Portable Antiquities of the Netherlands"

# Step 2: Use aggregation to count unique values in another field
group_field = "ore:describes.dansTemporalSpatial:dansSpatialCoverageText"

pipeline = [
    {"$match": {filter_field: filter_value}},  # Filter documents
    {"$group": {"_id": f"${group_field}", "count": {"$sum": 1}}},  # Group by unique values and count
    {"$sort": {"count": -1}},  # Sort by count in descending order
]

# Execute the pipeline
result = collection.aggregate(pipeline)

placenames = [] 

# Print the results
for item in result:
    print(f"Unique Value: {item['_id']}, Count: {item['count']}")
    plaats = item['_id'][0]
    placenames.append(plaats)
# Out:
# Unique Value: ['Bunnik', 'NLD'], Count: 8646
# Unique Value: ['Zaltbommel', 'NLD'], Count: 5167
# Unique Value: ['Overbetuwe', 'NLD'], Count: 5121
# Unique Value: ['Waadhoeke', 'NLD'], Count: 3776
# Unique Value: ['Buren', 'NLD'], Count: 3021
# Unique Value: ['West Betuwe', 'NLD'], Count: 2403
# Unique Value: ['Noardeast-Fryslân', 'NLD'], Count: 2103
# Unique Value: ['Grave', 'NLD'], Count: 2014
# Unique Value: ['Tiel', 'NLD'], Count: 1986
# Unique Value: ['Súdwest-Fryslân', 'NLD'], Count: 1594
# Unique Value: ['Texel', 'NLD'], Count: 1568
# Unique Value: ['Maasdriel', 'NLD'], Count: 1547
# Unique Value: ['Het Hogeland', 'NLD'], Count: 1375
# Unique Value: ['Neder-Betuwe', 'NLD'], Count: 1231
# Unique Value: ['Schouwen-Duiveland', 'NLD'], Count: 1116
# Unique Value: ['Leeuwarden', 'NLD'], Count: 1046
# Unique Value: ['Utrecht', 'NLD'], Count: 1023
# Unique Value: ["'s-Hertogenbosch", 'NLD'], Count: 995
# Unique Value: ['Sint Anthonis', 'NLD'], Count: 982
# Unique Value: ['Goes', 'NLD'], Count: 938
# Unique Value: ['Neerijnen', 'NLD'], Count: 930
# Unique Value: ['Zevenaar', 'NLD'], Count: 913
# Unique Value: ['Houten', 'NLD'], Count: 876
# Unique Value: ['Veere', 'NLD'], Count: 875
# Unique Value: ['Geldermalsen', 'NLD'], Count: 857
# Unique Value: ['Amsterdam', 'NLD'], Count: 854
# Unique Value: ['Maastricht', 'NLD'], Count: 852
# Unique Value: ['Oss', 'NLD'], Count: 793
# Unique Value: ['Nijmegen', 'NLD'], Count: 781
# Unique Value: ['Wijk bij Duurstede', 'NLD'], Count: 750
# Unique Value: ['Schagen', 'NLD'], Count: 728
# Unique Value: ['Alphen aan den Rijn', 'NLD'], Count: 704
# Unique Value: ['Sint-Michielsgestel', 'NLD'], Count: 685
# Unique Value: ['Reimerswaal', 'NLD'], Count: 682
# Unique Value: ['Den Helder', 'NLD'], Count: 670
# Unique Value: ['Sittard-Geleen', 'NLD'], Count: 639
# Unique Value: ['Meerssen', 'NLD'], Count: 636
# Unique Value: ['Katwijk', 'NLD'], Count: 630
# Unique Value: ['Harlingen', 'NLD'], Count: 579
# Unique Value: ['Bergen (NH.)', 'NLD'], Count: 563
# Unique Value: ['Dronten', 'NLD'], Count: 542
# Unique Value: ['De Fryske Marren', 'NLD'], Count: 534
# Unique Value: ['Harderwijk', 'NLD'], Count: 531
# Unique Value: ['Alkmaar', 'NLD'], Count: 512
# Unique Value: ['Loppersum', 'NLD'], Count: 496
# Unique Value: ['Duiven', 'NLD'], Count: 478
# Unique Value: ['Middelburg', 'NLD'], Count: 475
# Unique Value: ['Veldhoven', 'NLD'], Count: 464
# Unique Value: ['Maasgouw', 'NLD'], Count: 457
# Unique Value: ['Valkenburg aan de Geul', 'NLD'], Count: 454
# Unique Value: ['Berg en Dal', 'NLD'], Count: 450
# Unique Value: ['Hollands Kroon', 'NLD'], Count: 444
# Unique Value: ['Deventer', 'NLD'], Count: 442
# Unique Value: ['Roermond', 'NLD'], Count: 439
# Unique Value: ['Dongeradeel', 'NLD'], Count: 431
# Unique Value: ['Lochem', 'NLD'], Count: 430
# Unique Value: ['Berkelland', 'NLD'], Count: 425
# Unique Value: ['Leudal', 'NLD'], Count: 413
# Unique Value: ['Beesel', 'NLD'], Count: 402
# Unique Value: ['Bladel', 'NLD'], Count: 400
# Unique Value: ['Ouder-Amstel', 'NLD'], Count: 391
# Unique Value: ['Drechterland', 'NLD'], Count: 385
# Unique Value: ['Zutphen', 'NLD'], Count: 379
# Unique Value: ['Beuningen', 'NLD'], Count: 366
# Unique Value: ['Westerkwartier', 'NLD'], Count: 353
# Unique Value: ['Druten', 'NLD'], Count: 342
# Unique Value: ['Meierijstad', 'NLD'], Count: 338
# Unique Value: ['Breda', 'NLD'], Count: 336
# Unique Value: ['Ferwerderadiel', 'NLD'], Count: 335
# Unique Value: ['Cuijk', 'NLD'], Count: 331
# Unique Value: ['Castricum', 'NLD'], Count: 329
# Unique Value: ['Tytsjerksteradiel', 'NLD'], Count: 318
# Unique Value: ['Gooise Meren', 'NLD'], Count: 312
# Unique Value: ['Boxtel', 'NLD'], Count: 305
# Unique Value: ['Venlo', 'NLD'], Count: 296
# Unique Value: ['Voorst', 'NLD'], Count: 292
# Unique Value: ['De Ronde Venen', 'NLD'], Count: 290
# Unique Value: ['Sluis', 'NLD'], Count: 287
# Unique Value: ['Brummen', 'NLD'], Count: 281
# Unique Value: ['Heusden', 'NLD'], Count: 281
# Unique Value: ['De Bilt', 'NLD'], Count: 269
# Unique Value: ['Rotterdam', 'NLD'], Count: 264
# Unique Value: ['Land van Cuijk', 'NLD'], Count: 262
# Unique Value: ['Eijsden-Margraten', 'NLD'], Count: 260
# Unique Value: ['Mill en Sint Hubert', 'NLD'], Count: 255
# Unique Value: ['Groningen', 'NLD'], Count: 251
# Unique Value: ['Bernheze', 'NLD'], Count: 249
# Unique Value: ['De Marne', 'NLD'], Count: 248
# Unique Value: ['Delft', 'NLD'], Count: 247
# Unique Value: ['Weststellingwerf', 'NLD'], Count: 238
# Unique Value: ['Arnhem', 'NLD'], Count: 234
# Unique Value: ['Hulst', 'NLD'], Count: 233
# Unique Value: ['Westerwolde', 'NLD'], Count: 228
# Unique Value: ['Medemblik', 'NLD'], Count: 224
# Unique Value: ['Achtkarspelen', 'NLD'], Count: 224
# Unique Value: ['Delfzijl', 'NLD'], Count: 219
# Unique Value: ['Zuidhorn', 'NLD'], Count: 201
# Unique Value: ['Oirschot', 'NLD'], Count: 196
# Unique Value: ['Zoeterwoude', 'NLD'], Count: 194
# Unique Value: ['Eersel', 'NLD'], Count: 194
# Unique Value: ['Midden-Groningen', 'NLD'], Count: 194
# Unique Value: ['Vlissingen', 'NLD'], Count: 194
# Unique Value: ['Rhenen', 'NLD'], Count: 187
# Unique Value: ['Eemsdelta', 'NLD'], Count: 183
# Unique Value: ['Voerendaal', 'NLD'], Count: 179
# Unique Value: ['Haarlemmermeer', 'NLD'], Count: 177
# Unique Value: ['Waalwijk', 'NLD'], Count: 176
# Unique Value: ['Wijchen', 'NLD'], Count: 167
# Unique Value: ['Opmeer', 'NLD'], Count: 159
# Unique Value: ['Haarlem', 'NLD'], Count: 157
# Unique Value: ['Eemsmond', 'NLD'], Count: 153
# Unique Value: ['Lingewaard', 'NLD'], Count: 149
# Unique Value: ['Westland', 'NLD'], Count: 148
# Unique Value: ['Horst aan de Maas', 'NLD'], Count: 147
# Unique Value: ['Dordrecht', 'NLD'], Count: 147
# Unique Value: ['West Maas en Waal', 'NLD'], Count: 146
# Unique Value: ['Woerden', 'NLD'], Count: 136
# Unique Value: ['Velsen', 'NLD'], Count: 135
# Unique Value: ['Nijkerk', 'NLD'], Count: 131
# Unique Value: ['Steenwijkerland', 'NLD'], Count: 130
# Unique Value: ['Noord-Beveland', 'NLD'], Count: 125
# Unique Value: ['Heerde', 'NLD'], Count: 124
# Unique Value: ['Altena', 'NLD'], Count: 124
# Unique Value: ['Midden-Drenthe', 'NLD'], Count: 120
# Unique Value: ['Bergeijk', 'NLD'], Count: 119
# Unique Value: ['Gulpen-Wittem', 'NLD'], Count: 115
# Unique Value: ['Culemborg', 'NLD'], Count: 113
# Unique Value: ['Dongen', 'NLD'], Count: 112
# Unique Value: ['Uden', 'NLD'], Count: 108
# Unique Value: ['Opsterland', 'NLD'], Count: 106
# Unique Value: ['Goeree-Overflakkee', 'NLD'], Count: 105
# Unique Value: ["'s-Gravenhage", 'NLD'], Count: 103
# Unique Value: ['Oldambt', 'NLD'], Count: 103
# Unique Value: ['Weert', 'NLD'], Count: 99
# Unique Value: ['Aa en Hunze', 'NLD'], Count: 98
# Unique Value: ['Winsum', 'NLD'], Count: 96
# Unique Value: ['Montferland', 'NLD'], Count: 96
# Unique Value: ['Brielle', 'NLD'], Count: 96
# Unique Value: ['Geertruidenberg', 'NLD'], Count: 95
# Unique Value: ['Uitgeest', 'NLD'], Count: 94
# Unique Value: ['Nuenen, Gerwen en Nederwetten', 'NLD'], Count: 93
# Unique Value: ['Heumen', 'NLD'], Count: 92
# Unique Value: ['Oegstgeest', 'NLD'], Count: 92
# Unique Value: ['Echt-Susteren', 'NLD'], Count: 92
# Unique Value: ['Oudewater', 'NLD'], Count: 88
# Unique Value: ['IJsselstein', 'NLD'], Count: 88
# Unique Value: ['Westerveld', 'NLD'], Count: 88
# Unique Value: ['Eindhoven', 'NLD'], Count: 88
# Unique Value: ['Someren', 'NLD'], Count: 87
# Unique Value: ['Landerd', 'NLD'], Count: 86
# Unique Value: ['Peel en Maas', 'NLD'], Count: 86
# Unique Value: ['Boxmeer', 'NLD'], Count: 85
# Unique Value: ['Kaag en Braassem', 'NLD'], Count: 81
# Unique Value: ['Borger-Odoorn', 'NLD'], Count: 81
# Unique Value: ['Asten', 'NLD'], Count: 76
# Unique Value: ['Aalburg', 'NLD'], Count: 74
# Unique Value: ['Smallingerland', 'NLD'], Count: 73
# Unique Value: ['Noordoostpolder', 'NLD'], Count: 70
# Unique Value: ['Landsmeer', 'NLD'], Count: 68
# Unique Value: ['Reusel-De Mierden', 'NLD'], Count: 66
# Unique Value: ['Landgraaf', 'NLD'], Count: 64
# Unique Value: ['Amersfoort', 'NLD'], Count: 61
# Unique Value: ['Roerdalen', 'NLD'], Count: 60
# Unique Value: ['Vught', 'NLD'], Count: 59
# Unique Value: ['Laarbeek', 'NLD'], Count: 56
# Unique Value: ['Dantumadiel', 'NLD'], Count: 54
# Unique Value: ['Terschelling', 'NLD'], Count: 53
# Unique Value: ['Vijfheerenlanden', 'NLD'], Count: 51
# Unique Value: ['Waterland', 'NLD'], Count: 51
# Unique Value: ['Kapelle', 'NLD'], Count: 51
# Unique Value: ['Beekdaelen', 'NLD'], Count: 50
# Unique Value: ['Hilversum', 'NLD'], Count: 50
# Unique Value: ['Leiderdorp', 'NLD'], Count: 49
# Unique Value: ['Heerenveen', 'NLD'], Count: 48
# Unique Value: ['Meppel', 'NLD'], Count: 48
# Unique Value: ['Waddinxveen', 'NLD'], Count: 48
# Unique Value: ['Simpelveld', 'NLD'], Count: 47
# Unique Value: ['Leiden', 'NLD'], Count: 45
# Unique Value: ['Borsele', 'NLD'], Count: 45
# Unique Value: ['Etten-Leur', 'NLD'], Count: 45
# Unique Value: ['Stichtse Vecht', 'NLD'], Count: 45
# Unique Value: ['Amstelveen', 'NLD'], Count: 45
# Unique Value: ['Venray', 'NLD'], Count: 44
# Unique Value: ['Hardenberg', 'NLD'], Count: 44
# Unique Value: ['Lelystad', 'NLD'], Count: 44
# Unique Value: ['Wijdemeren', 'NLD'], Count: 43
# Unique Value: ['Gilze en Rijen', 'NLD'], Count: 43
# Unique Value: ['Alphen-Chaam', 'NLD'], Count: 42
# Unique Value: ['Veendam', 'NLD'], Count: 42
# Unique Value: ['Midden-Delfland', 'NLD'], Count: 42
# Unique Value: ['Gemert-Bakel', 'NLD'], Count: 40
# Unique Value: ['Waalre', 'NLD'], Count: 40
# Unique Value: ['Heeze-Leende', 'NLD'], Count: 40
# Unique Value: ['Oosterhout', 'NLD'], Count: 40
# Unique Value: ['Heiloo', 'NLD'], Count: 39
# Unique Value: ['Elburg', 'NLD'], Count: 39
# Unique Value: ['Son en Breugel', 'NLD'], Count: 39
# Unique Value: ['Huizen', 'NLD'], Count: 38
# Unique Value: ['Geldrop-Mierlo', 'NLD'], Count: 38
# Unique Value: ['Montfoort', 'NLD'], Count: 37
# Unique Value: ['Tholen', 'NLD'], Count: 36
# Unique Value: ['Kampen', 'NLD'], Count: 36
# Unique Value: ['Westervoort', 'NLD'], Count: 36
# Unique Value: ['Zwartewaterland', 'NLD'], Count: 36
# Unique Value: ['Ameland', 'NLD'], Count: 35
# Unique Value: ['Westvoorne', 'NLD'], Count: 34
# Unique Value: ['Leidschendam-Voorburg', 'NLD'], Count: 34
# Unique Value: ['Zundert', 'NLD'], Count: 33
# Unique Value: ['Terneuzen', 'NLD'], Count: 32
# Unique Value: ['Halderberge', 'NLD'], Count: 32
# Unique Value: ['Raalte', 'NLD'], Count: 32
# Unique Value: ['Rheden', 'NLD'], Count: 32
# Unique Value: ['Utrechtse Heuvelrug', 'NLD'], Count: 32
# Unique Value: ['Noordenveld', 'NLD'], Count: 31
# Unique Value: ['Loon op Zand', 'NLD'], Count: 31
# Unique Value: ['Cranendonck', 'NLD'], Count: 29
# Unique Value: ['Enkhuizen', 'NLD'], Count: 29
# Unique Value: ['Doesburg', 'NLD'], Count: 29
# Unique Value: ['Tynaarlo', 'NLD'], Count: 29
# Unique Value: ['Kollumerland en Nieuwkruisland', 'NLD'], Count: 29
# Unique Value: ['Oude IJsselstreek', 'NLD'], Count: 28
# Unique Value: ['Pijnacker-Nootdorp', 'NLD'], Count: 28
# Unique Value: ['De Wolden', 'NLD'], Count: 28
# Unique Value: ['Moerdijk', 'NLD'], Count: 27
# Unique Value: ['Ommen', 'NLD'], Count: 27
# Unique Value: ['Nieuwkoop', 'NLD'], Count: 26
# Unique Value: ['Edam-Volendam', 'NLD'], Count: 26
# Unique Value: ['Dalfsen', 'NLD'], Count: 26
# Unique Value: ['Stede Broec', 'NLD'], Count: 25
# Unique Value: ['Heerlen', 'NLD'], Count: 24
# Unique Value: ['Bronckhorst', 'NLD'], Count: 24
# Unique Value: ['Wageningen', 'NLD'], Count: 24
# Unique Value: ['Molenlanden', 'NLD'], Count: 23
# Unique Value: ['Zwolle', 'NLD'], Count: 23
# Unique Value: ['Hilvarenbeek', 'NLD'], Count: 23
# Unique Value: ['Dinkelland', 'NLD'], Count: 22
# Unique Value: ['Zuidplas', 'NLD'], Count: 22
# Unique Value: ['Ten Boer', 'NLD'], Count: 22
# Unique Value: ['Roosendaal', 'NLD'], Count: 22
# Unique Value: ['Deurne', 'NLD'], Count: 22
# Unique Value: ['Twenterand', 'NLD'], Count: 22
# Unique Value: ['Olst-Wijhe', 'NLD'], Count: 21
# Unique Value: ['Heemskerk', 'NLD'], Count: 21
# Unique Value: ['Maashorst', 'NLD'], Count: 20
# Unique Value: ['Tilburg', 'NLD'], Count: 20
# Unique Value: ['Beemster', 'NLD'], Count: 20
# Unique Value: ['Hoorn', 'NLD'], Count: 20
# Unique Value: ['Bergen (L.)', 'NLD'], Count: 20
# Unique Value: ['Voorne aan Zee', 'NLD'], Count: 20
# Unique Value: ['Soest', 'NLD'], Count: 20
# Unique Value: ['Diemen', 'NLD'], Count: 19
# Unique Value: ['Staphorst', 'NLD'], Count: 19
# Unique Value: ['Bergen op Zoom', 'NLD'], Count: 18
# Unique Value: ['Helmond', 'NLD'], Count: 18
# Unique Value: ['Gouda', 'NLD'], Count: 18
# Unique Value: ['Weesp', 'NLD'], Count: 18
# Unique Value: ['Stadskanaal', 'NLD'], Count: 17
# Unique Value: ['Baarle-Nassau', 'NLD'], Count: 17
# Unique Value: ['Hoeksche Waard', 'NLD'], Count: 16
# Unique Value: ['Oisterwijk', 'NLD'], Count: 15
# Unique Value: ['Heerhugowaard', 'NLD'], Count: 15
# Unique Value: ['Zeist', 'NLD'], Count: 15
# Unique Value: ['Vaals', 'NLD'], Count: 14
# Unique Value: ['Woudrichem', 'NLD'], Count: 14
# Unique Value: ['Hellevoetsluis', 'NLD'], Count: 13
# Unique Value: ['Bunschoten', 'NLD'], Count: 12
# Unique Value: ['Bedum', 'NLD'], Count: 12
# Unique Value: ['Stein', 'NLD'], Count: 12
# Unique Value: ['Heemstede', 'NLD'], Count: 11
# Unique Value: ['Hengelo', 'NLD'], Count: 11
# Unique Value: ['Zwijndrecht', 'NLD'], Count: 11
# Unique Value: ['Kerkrade', 'NLD'], Count: 11
# Unique Value: ['Nissewaard', 'NLD'], Count: 11
# Unique Value: ['Doetinchem', 'NLD'], Count: 11
# Unique Value: ['Koggenland', 'NLD'], Count: 11
# Unique Value: ['Wierden', 'NLD'], Count: 11
# Unique Value: ['Langedijk', 'NLD'], Count: 10
# Unique Value: ['Haaren', 'NLD'], Count: 10
# Unique Value: ['Schinnen', 'NLD'], Count: 10
# Unique Value: ['Ooststellingwerf', 'NLD'], Count: 10
# Unique Value: ['Gennep', 'NLD'], Count: 10
# Unique Value: ['P08', 'NLD'], Count: 10
# Unique Value: ['Voorschoten', 'NLD'], Count: 9
# Unique Value: ['Coevorden', 'NLD'], Count: 9
# Unique Value: ['Leusden', 'NLD'], Count: 9
# Unique Value: ['Beverwijk', 'NLD'], Count: 9
# Unique Value: ['Goirle', 'NLD'], Count: 9
# Unique Value: ['Noordwijk', 'NLD'], Count: 9
# Unique Value: ['Assen', 'NLD'], Count: 8
# Unique Value: ['Almere', 'NLD'], Count: 8
# Unique Value: ['Hellendoorn', 'NLD'], Count: 8
# Unique Value: ['Enschede', 'NLD'], Count: 8
# Unique Value: ['Bodegraven-Reeuwijk', 'NLD'], Count: 7
# Unique Value: ['Nieuwegein', 'NLD'], Count: 7
# Unique Value: ['Winterswijk', 'NLD'], Count: 7
# Unique Value: ['Mook en Middelaar', 'NLD'], Count: 7
# Unique Value: ['Borne', 'NLD'], Count: 7
# Unique Value: ['Brunssum', 'NLD'], Count: 7
# Unique Value: ['Bloemendaal', 'NLD'], Count: 7
# Unique Value: ['Haaksbergen', 'NLD'], Count: 7
# Unique Value: ['Emmen', 'NLD'], Count: 6
# Unique Value: ['Tubbergen', 'NLD'], Count: 6
# Unique Value: ['Uithoorn', 'NLD'], Count: 6
# Unique Value: ['Rijssen-Holten', 'NLD'], Count: 6
# Unique Value: ['Hof van Twente', 'NLD'], Count: 6
# Unique Value: ['Nuth', 'NLD'], Count: 6
# Unique Value: ['Barneveld', 'NLD'], Count: 6
# Unique Value: ['Rijswijk', 'NLD'], Count: 5
# Unique Value: ['Lansingerland', 'NLD'], Count: 5
# Unique Value: ['Appingedam', 'NLD'], Count: 5
# Unique Value: ['Oostzaan', 'NLD'], Count: 5
# Unique Value: ['Losser', 'NLD'], Count: 5
# Unique Value: ['P15', 'NLD'], Count: 5
# Unique Value: ['Vianen', 'NLD'], Count: 5
# Unique Value: ['Teylingen', 'NLD'], Count: 5
# Unique Value: ['Drimmelen', 'NLD'], Count: 5
# Unique Value: ['Grootegast', 'NLD'], Count: 5
# Unique Value: ['Wassenaar', 'NLD'], Count: 5
# Unique Value: ['Oldebroek', 'NLD'], Count: 4
# Unique Value: ['Ermelo', 'NLD'], Count: 4
# Unique Value: ['Hattem', 'NLD'], Count: 4
# Unique Value: ['Laren', 'NLD'], Count: 4
# Unique Value: ['Nederweert', 'NLD'], Count: 4
# Unique Value: ['Marum', 'NLD'], Count: 4
# Unique Value: ['Krimpenerwaard', 'NLD'], Count: 4
# Unique Value: ['Oost Gelre', 'NLD'], Count: 4
# Unique Value: ['Zeewolde', 'NLD'], Count: 4
# Unique Value: ['Baarn', 'NLD'], Count: 4
# Unique Value: ['Eemnes', 'NLD'], Count: 4
# Unique Value: ['Leerdam', 'NLD'], Count: 4
# Unique Value: ['Gorinchem', 'NLD'], Count: 4
# Unique Value: ['Purmerend', 'NLD'], Count: 4
# Unique Value: ['Zaanstad', 'NLD'], Count: 3
# Unique Value: ['Lopik', 'NLD'], Count: 3
# Unique Value: ['Best', 'NLD'], Count: 3
# Unique Value: ['Aalten', 'NLD'], Count: 3
# Unique Value: ['Valkenswaard', 'NLD'], Count: 3
# Unique Value: ['Haren', 'NLD'], Count: 3
# Unique Value: ['L15', 'NLD'], Count: 2
# Unique Value: ['Maassluis', 'NLD'], Count: 2
# Unique Value: ['Epe', 'NLD'], Count: 2
# Unique Value: ['Pekela', 'NLD'], Count: 2
# Unique Value: ['Rucphen', 'NLD'], Count: 2
# Unique Value: ['Capelle aan den IJssel', 'NLD'], Count: 2
# Unique Value: ['Vlaardingen', 'NLD'], Count: 2
# Unique Value: ['Alblasserdam', 'NLD'], Count: 2
# Unique Value: ['Veenendaal', 'NLD'], Count: 2
# Unique Value: ['Urk', 'NLD'], Count: 1
# Unique Value: ['S02', 'NLD'], Count: 1
# Unique Value: ['Binnenmaas', 'NLD'], Count: 1
# Unique Value: ['Putten', 'NLD'], Count: 1
# Unique Value: ['Wormerland', 'NLD'], Count: 1
# Unique Value: ['Ede', 'NLD'], Count: 1
# Unique Value: ['P18', 'NLD'], Count: 1
# Unique Value: ['Woudenberg', 'NLD'], Count: 1
# Unique Value: ['Ridderkerk', 'NLD'], Count: 1
# Unique Value: ['Nunspeet', 'NLD'], Count: 1
# Unique Value: ['Oldenzaal', 'NLD'], Count: 1
# Unique Value: ['Steenbergen', 'NLD'], Count: 1
# Unique Value: ['Schiedam', 'NLD'], Count: 1
# Unique Value: ['Zandvoort', 'NLD'], Count: 1
# Unique Value: ['Blaricum', 'NLD'], Count: 1
# Unique Value: ['Renkum', 'NLD'], Count: 1
# Unique Value: ['R06', 'NLD'], Count: 1
# Unique Value: ['Beek', 'NLD'], Count: 1
# Unique Value: ['P12', 'NLD'], Count: 1
# Unique Value: ['L02', 'NLD'], Count: 1
# Unique Value: ['Apeldoorn', 'NLD'], Count: 1

# %%
# If number in name: remove 

print(len(placenames))
# Out:
# 368

# %%
print(placenames)
# Out:
# ['Bunnik', 'Zaltbommel', 'Overbetuwe', 'Waadhoeke', 'Buren', 'West Betuwe', 'Noardeast-Fryslân', 'Grave', 'Tiel', 'Súdwest-Fryslân', 'Texel', 'Maasdriel', 'Het Hogeland', 'Neder-Betuwe', 'Schouwen-Duiveland', 'Leeuwarden', "'s-Hertogenbosch", 'Utrecht', 'Sint Anthonis', 'Goes', 'Neerijnen', 'Zevenaar', 'Veere', 'Geldermalsen', 'Amsterdam', 'Maastricht', 'Houten', 'Oss', 'Nijmegen', 'Wijk bij Duurstede', 'Schagen', 'Alphen aan den Rijn', 'Reimerswaal', 'Den Helder', 'Sint-Michielsgestel', 'Sittard-Geleen', 'Meerssen', 'Katwijk', 'Harlingen', 'Bergen (NH.)', 'Dronten', 'De Fryske Marren', 'Harderwijk', 'Alkmaar', 'Loppersum', 'Duiven', 'Middelburg', 'Veldhoven', 'Maasgouw', 'Valkenburg aan de Geul', 'Berg en Dal', 'Deventer', 'Hollands Kroon', 'Roermond', 'Dongeradeel', 'Lochem', 'Berkelland', 'Leudal', 'Beesel', 'Bladel', 'Ouder-Amstel', 'Drechterland', 'Zutphen', 'Beuningen', 'Westerkwartier', 'Druten', 'Meierijstad', 'Breda', 'Ferwerderadiel', 'Cuijk', 'Castricum', 'Tytsjerksteradiel', 'Gooise Meren', 'Venlo', 'De Ronde Venen', 'Voorst', 'Boxtel', 'Sluis', 'Heusden', 'Brummen', 'De Bilt', 'Eijsden-Margraten', 'Rotterdam', 'Mill en Sint Hubert', 'Land van Cuijk', 'Bernheze', 'De Marne', 'Delft', 'Groningen', 'Weststellingwerf', 'Arnhem', 'Hulst', 'Westerwolde', 'Achtkarspelen', 'Medemblik', 'Delfzijl', 'Zuidhorn', 'Eersel', 'Vlissingen', 'Midden-Groningen', 'Oirschot', 'Zoeterwoude', 'Rhenen', 'Voerendaal', 'Haarlemmermeer', 'Eemsdelta', 'Waalwijk', 'Opmeer', 'Haarlem', 'Eemsmond', 'Wijchen', 'Lingewaard', 'Westland', 'Horst aan de Maas', 'Dordrecht', 'West Maas en Waal', 'Woerden', 'Velsen', 'Nijkerk', 'Steenwijkerland', 'Noord-Beveland', 'Heerde', 'Altena', 'Bergeijk', 'Midden-Drenthe', 'Gulpen-Wittem', 'Culemborg', 'Dongen', 'Uden', 'Goeree-Overflakkee', 'Opsterland', "'s-Gravenhage", 'Oldambt', 'Aa en Hunze', 'Weert', 'Winsum', 'Brielle', 'Geertruidenberg', 'Montferland', 'Uitgeest', 'Oegstgeest', 'Echt-Susteren', 'Heumen', 'Nuenen, Gerwen en Nederwetten', 'IJsselstein', 'Oudewater', 'Westerveld', 'Eindhoven', 'Someren', 'Landerd', 'Boxmeer', 'Peel en Maas', 'Kaag en Braassem', 'Borger-Odoorn', 'Asten', 'Aalburg', 'Smallingerland', 'Noordoostpolder', 'Landsmeer', 'Reusel-De Mierden', 'Landgraaf', 'Roerdalen', 'Amersfoort', 'Vught', 'Laarbeek', 'Terschelling', 'Dantumadiel', 'Waterland', 'Kapelle', 'Vijfheerenlanden', 'Hilversum', 'Beekdaelen', 'Leiderdorp', 'Heerenveen', 'Waddinxveen', 'Meppel', 'Simpelveld', 'Leiden', 'Amstelveen', 'Borsele', 'Etten-Leur', 'Venray', 'Stichtse Vecht', 'Hardenberg', 'Wijdemeren', 'Gilze en Rijen', 'Alphen-Chaam', 'Veendam', 'Midden-Delfland', 'Lelystad', 'Heeze-Leende', 'Oosterhout', 'Waalre', 'Heiloo', 'Elburg', 'Geldrop-Mierlo', 'Huizen', 'Montfoort', 'Kampen', 'Gemert-Bakel', 'Westervoort', 'Tholen', 'Son en Breugel', 'Ameland', 'Westvoorne', 'Leidschendam-Voorburg', 'Zwartewaterland', 'Zundert', 'Rheden', 'Terneuzen', 'Halderberge', 'Loon op Zand', 'Utrechtse Heuvelrug', 'Noordenveld', 'Kollumerland en Nieuwkruisland', 'Tynaarlo', 'Cranendonck', 'Enkhuizen', 'De Wolden', 'Doesburg', 'Pijnacker-Nootdorp', 'Moerdijk', 'Oude IJsselstreek', 'Ommen', 'Raalte', 'Edam-Volendam', 'Dalfsen', 'Stede Broec', 'Nieuwkoop', 'Heerlen', 'Wageningen', 'Hilvarenbeek', 'Zwolle', 'Molenlanden', 'Bronckhorst', 'Deurne', 'Ten Boer', 'Zuidplas', 'Roosendaal', 'Dinkelland', 'Twenterand', 'Olst-Wijhe', 'Heemskerk', 'Soest', 'Bergen (L.)', 'Beemster', 'Hoorn', 'Tilburg', 'Maashorst', 'Voorne aan Zee', 'Bergen op Zoom', 'Helmond', 'Gouda', 'Weesp', 'Staphorst', 'Diemen', 'Baarle-Nassau', 'Hoeksche Waard', 'Stadskanaal', 'Heerhugowaard', 'Zeist', 'Oisterwijk', 'Vaals', 'Woudrichem', 'Hellevoetsluis', 'Bunschoten', 'Bedum', 'Stein', 'Hengelo', 'Nissewaard', 'Doetinchem', 'Wierden', 'Zwijndrecht', 'Koggenland', 'Heemstede', 'Kerkrade', 'Ooststellingwerf', 'Haaren', 'Gennep', 'Langedijk', 'P08', 'Schinnen', 'Leusden', 'Beverwijk', 'Coevorden', 'Noordwijk', 'Hellendoorn', 'Voorschoten', 'Assen', 'Enschede', 'Bloemenda ...

# %%
# # Write to .txt file 
# with open('../../data/plaatsnamen.txt', 'w') as f:
#     for item in placenames:
#         f.write("%s\n" % item)
